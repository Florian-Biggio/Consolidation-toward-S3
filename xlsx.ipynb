# %%
import sys
import json
import re
import argparse
from datetime import datetime
from io import BytesIO
import os

import pandas as pd
import boto3
from pymongo import MongoClient

# %%
def load_secrets(file_path):
    if not os.path.exists(file_path):
        print(f"Error: {file_path} not found!")
        sys.exit(1)
    
    with open(file_path, 'r') as file:
        return json.load(file)
secrets = load_secrets('secrets.json')

aws_access_key_id = secrets['AWS_ACCESS_KEY_ID']
aws_secret_access_key = secrets['AWS_SECRET_ACCESS_KEY']
aws_region = secrets['AWS_REGION']

# %%
# Delete if not in Jupyter Notebook
if 'ipykernel' in sys.modules:
    sys.argv = ['mongoTransfert.py', 'Ichtegem']  


parser = argparse.ArgumentParser(description="Process an Excel file")
parser.add_argument(
    'files',
    nargs='*',  # Accept multiple files (or none)
    default=None,
    help='The name of the station to process. Only accepts Ichtegem or Madeleine'
)
args = parser.parse_args()

if not args.files:
    args.files = ['Ichtegem']

# %%
args.files[0]
# Out:
# 'Ichtegem'

# %%
s3 = boto3.client('s3', 
                  aws_access_key_id=aws_access_key_id, 
                  aws_secret_access_key=aws_secret_access_key, 
                  region_name=aws_region)

# %%
bucket_name = 'greencoop-airbyte'
if args.files[0] == 'Ichtegem':
    file_key = "greencoop-airbyte/Ichtegem.xlsx"
elif args.files[0] == 'Madeleine':
    file_key = "greencoop-airbyte/Madeleine.xlsx"

s3_object = s3.get_object(Bucket=bucket_name, Key=file_key)
file_content = s3_object['Body'].read()

# Charger le fichier Excel avec pandas
excel_file = pd.ExcelFile(BytesIO(file_content), engine='openpyxl')

# %%
# Define column renaming dictionary (with explicit units)
column_mapping = {
    "Time": "time",
    "Temperature": "temperature_°F",
    "Dew Point": "dew_point_°F",
    "Humidity": "humidity_%",
    "Wind": "wind_dir",
    "Speed": "wind_speed_mph",
    "Gust": "wind_gust_mph",
    "Pressure": "pressure_inHg",
    "Precip. Rate.": "precip_rate_in/hr",
    "Precip. Accum.": "precip_accum_in",
    "UV": "uv_index",
    "Solar": "solar_w/m²"
}

def clean_value(value):
    if isinstance(value, str):
        match = re.search(r"[-+]?\d*\.?\d+", value)  # Extract numeric part
        return float(match.group()) if match else None  # Keep None for non-numeric strings
    return value  # Return unchanged if not a string (including NaN)


# List to store processed DataFrames
dfs = []

# Loop through all sheets
for sheet_name in excel_file.sheet_names:
    # Read the current sheet
    df = excel_file.parse(sheet_name, na_values=["", "None", "NA", "NaN"])
    # Rename columns for consistency
    df.rename(columns=column_mapping, inplace=True)
    
    # Apply cleaning function to all columns (except 'time' and 'wind_dir')
    for col in df.columns:
        if col not in ["time", "wind_dir"]:  # Exclude categorical columns
            df[col] = df[col].apply(clean_value)

    df = df.dropna(how='all')

    # Convert sheet name (DDMMAAAA) to date (YYYY-MM-DD)
    date_formatted = pd.to_datetime(sheet_name, format="%d%m%y")
    
    # Add the date column
    df.insert(0, "date", date_formatted)
    df["time"] = pd.to_datetime(df["time"], format="%H:%M:%S").dt.time
    df["datetime"] = pd.to_datetime(df["date"].astype(str) + " " + df["time"].astype(str))
    df = df.drop(columns=["date", "time"])
    df = df[["datetime"] + [col for col in df.columns if col != "datetime"]]

    # Append cleaned DataFrame
    dfs.append(df)

# Combine all sheets into one DataFrame
final_df = pd.concat(dfs, ignore_index=True)
# Out:
#                datetime  temperature_°F  dew_point_°F  humidity_% wind_dir  \
# 1   2024-10-07 00:04:00            57.7          56.7        96.0       SW
# 2   2024-10-07 00:09:00            57.7          56.7        96.0       SW
# 3   2024-10-07 00:14:00            57.8          56.8        96.0      WSW
# 4   2024-10-07 00:19:00            58.0          56.9        96.0      WSW
# 5   2024-10-07 00:24:00            58.2          57.2        96.0      WSW
# ..                  ...             ...           ...         ...      ...
# 174 2024-10-07 14:29:00            65.2          56.3        73.0      WSW
# 175 2024-10-07 14:34:00            65.5          56.3        72.0      WSW
# 176 2024-10-07 14:39:00            65.7          55.5        70.0      WSW
# 177 2024-10-07 14:44:00            66.4          56.1        70.0     West
# 178 2024-10-07 14:49:00            66.4          55.7        68.0      WSW
#
#      wind_speed_mph  wind_gust_mph  pressure_inHg  precip_rate_in/hr  \
# 1               2.4            3.5          29.27                0.0
# 2               2.0            2.9          29.28                0.0
# 3               2.5            3.3          29.28                0.0
# 4               3.0            4.0          29.28                0.0
# 5               3.2            4.4          29.28                0.0
# ..              ...            ...            ...                ...
# 174             3.7            4.8          29.37                0.0
# 175             3.4            4.2          29.36                0.0
# 176             4.3            6.1          29.36                0.0
# 177             2.9            4.1          29.36                0.0
# 178             2.7            4.2          29.36                0.0
#
#      precip_accum_in  uv_index  solar_w/m²
# 1               0.00       0.0         0.0
# 2               0.00       0.0         0.0
# 3               0.00       0.0         0.0
# 4               0.00       0.0         0.0
# 5               0.00       0.0         0.0
# ..               ...       ...         ...
# 174             0.01       4.0       414.8
# 175             0.01       4.0       416.6
# 176             0.01       3.0       338.5
# 177             0.01       3.0       349.6
# 178             0.01       3.0       345.7
#
# [178 rows x 12 columns]
#
#
#          Time Temperature Dew Point Humidity   Wind     Speed      Gust  \
# 0         NaN         NaN       NaN      NaN    NaN       NaN       NaN
# 1    00:04:00     56.8 °F   53.1 °F     87 %    WSW   8.2 mph  10.4 mph
# 2    00:09:00     56.8 °F   52.9 °F     87 %    WSW   7.9 mph   9.8 mph
# 3    00:14:00     57.0 °F   52.8 °F     86 %   West  10.3 mph  12.8 mph
# 4    00:19:00     57.2 °F   52.7 °F     85 %    WSW   9.7 mph  12.2 mph
# ..        ...         ...       ...      ...    ...       ...       ...
# 284  23:39:00     51.1 °F   50.0 °F     96 %  South   2.1 mph   2.8 mph
# 285  23:44:00     51.3 °F   50.2 °F     96 %  South   1.7 mph   2.4 mph
# 286  23:49:00     51.3 °F   50.2 °F     96 %  South   1.6 mph   2.3 mph
# 287  23:54:00     51.3 °F   50.4 °F     96 %  South   2.2 mph   3.0 mph
# 288  23:59:00     51.3 °F   50.2 °F     96 %  South   2.0 mph   2.8 mph
#
#      Pressure Precip. Rate. Precip. Accum.   UV   Solar
# 0         NaN           NaN            NaN  NaN     NaN
# 1    29.48 in       0.00 in        0.00 in  0.0  0 w/m²
# 2    29.47 in       0.00 in        0.00 in  0.0  0 w/m²
# 3    29.47 in       0.00 in        0.00 in  0.0  0 w/m²
# 4    29.47 in       0.00 in        0.00 in  0.0  0 w/m²
# ..        ...           ...            ...  ...     ...
# 284  29.45 in       0.00 in        0.18 in  0.0  0 w/m²
# 285  29.45 in       0.00 in        0.18 in  0.0  0 w/m²
# 286  29.46 in       0.00 in        0.18 in  0.0  0 w/m²
# 287  29.45 in       0.00 in        0.18 in  0.0  0 w/m²
# 288  29.46 in       0.00 in        0.18 in  0.0  0 w/m²
#
# [289 rows x 12 columns]
#                datetime  temperature_°F  dew_point_°F  humidity_% wind_dir  \
# 1   2024-10-01 00:04:00            56.8          53.1        87.0      WSW
# 2   2024-10-01 00:09:00            56.8          52.9        87.0      WSW
# 3   2024-10-01 00:14:00            57.0          52.8        86.0     West
# 4   2024-10-01 00:19:00            57.2          52.7        85.0      WSW
# 5   2024-10-01 00:24:00            57.2          52.7        85.0      WSW
# ..                  ...             ...           ...         ...      ...
# 284 2024-10-01 23:39:00            51.1          50.0        96.0    South
# 285 2024-10-01 23:44:00            51.3          50.2        96.0    South
# 286 2024-10-01 23:49:00            51.3          50.2        96.0    South
# 287 2024-10-01 23:54:00            51.3          50.4        96.0    South
# 288 2024-10-01 23:59:00            51.3          50.2        96.0    South
#
#      wind_speed_mph  wind_gust_mph  pressure_inHg  precip_rate_in/hr  \
# 1               8.2           10.4          29.48                0.0
# 2               7.9            9.8          29.47                0.0
# 3              10.3           12.8          29.47                0.0
# 4               9.7           12.2          29.47                0.0
# 5               9.7           11.9          29.47                0.0
# ..              ...            ...            ...                ...
# 284             2.1            2.8          29.45                0.0
# 285             1.7            2.4          29.45                0.0
# 286             1.6            2.3          29.46                0.0
# 287             2.2            3.0          29.45                0.0
# 288             2.0            2.8          29.46                0.0
#
#      precip_accum_in  uv_index  solar_w/m²
# 1               0.00       0.0         0.0
# 2               0.00       0.0         0.0
# 3               0.00       0.0         0.0
# 4               0.00       0.0         0.0
# 5               0.00       0.0         0.0
# ..               ...       ...         ...
# 284             0.18       0.0         0.0
# 285             0.18       0.0         0.0
# 286             0.18       0.0         0.0
# 287             0.18       0.0         0.0
# 288             0.18       0.0         0.0
#
# [288 rows x 12 columns]
#
#
#          Time Temperature Dew Point Humidity   Wind    Speed     Gust  \
# 0         NaN         NaN       NaN      NaN    NaN      NaN      NaN
# 1    00:04:00     51.2 °F   50.2 °F     96 %  South  1.4 mph  1.9 mph
# 2    00:09:00     51.1 °F   50.3 °F     97 %  South  1.0 mph  1.5 mph
# 3    00:14:00     51.0 °F   50.0 °F     96 %  South  1.0 mph  1.7 mph
# 4    00:19:00     50.7 °F   50.0 °F     97 %  South  1.1 mph  1.5 mph
# ..        ...         ...       ...      ...    ...      ...      ...
# 281  23:39:00     53.1 °F   48.4 °F     84 %     NE  4.5 mph  6.0 mph
# 282  23:44:00     52.9 °F   48.2 °F     84 %     NE  4.5 mph  5.9 mph
# 283  23:49:00     52.9 °F   48.3 °F     84 %     NE  3.6 mph  5.0 mph
# 284  23:54:00     52.9 °F   48.3 °F     84 %    NNE  5.8 mph  7.8 mph
# 285  23:59:00     52.9 °F   48.5 °F     85 %    NNE  3.7 mph  5.2 mph
#
#      Pressure Precip. Rate. Precip. Accum.   UV   Solar
# 0         NaN           NaN            NaN  NaN     NaN
# 1    29.46 in       0.00 in        0.00 in  0.0  0 w/m²
# 2    29.46 in       0.00 in        0.00 in  0.0  0 w/m²
# 3    29.47 in       0.00 in        0.00 in  0.0  0 w/m²
# 4    29.47 in       0.00 in        0.00 in  0.0  0 w/m²
# ..        ...           ...            ...  ...     ...
# 281  29.79 in       0.00 in        0.01 in  0.0  0 w/m²
# 282  29.80 in       0.00 in        0.01 in  0.0  0 w/m²
# 283  29.80 in       0.00 in        0.01 in  0.0  0 w/m²
# 284  29.80 in       0.00 in        0.01 in  0.0  0 w/m²
# 285  29.80 in       0.00 in        0.01 in  0.0  0 w/m²
#
# [286 rows x 12 columns]
#                datetime  temperature_°F  dew_point_°F  humidity_% wind_dir  \
# 1   2024-10-02 00:04:00            51.2          50.2        96.0    South
# 2   2024-10-02 00:09:00            51.1          50.3        97.0    South
# 3   2024-10-02 00:14:00            51.0          50.0        96.0    South
# 4   2024-10-02 00:19:00            50.7          50.0        97.0    South
# 5   2024-10-02 00:24:00            50.7          50.0        97.0    South
# ..                  ...             ...           ...         ...      ...
# 281 2024-10-02 23:39:00            53.1          48.4        84.0       NE
# 282 2024-10-02 23:44:00            52.9          48.2        84.0       NE
# 283 2024-10-02 23:49:00            52.9          48.3        84.0       NE
# 284 2024-10-02 23:54:00            52.9          48.3        84.0      NNE
# 285 2024-10-02 23:59:00            52.9          48.5        85.0      NNE
#
#      wind_speed_mph  wind_gust_mph  pressure_inHg  precip_rate_in/hr  \
# 1               1.4            1.9          29.46                0.0
# 2               1.0            1.5          29.46                0.0
# 3               1.0            1.7          29.47                0.0
# 4               1.1            1.5          29.47                0.0
# 5               1.2            1.7          29.47                0.0
# ..              ...            ...            ...                ...
# 281             4.5            6.0          29.79                0.0
# 282             4.5            5.9          29.80                0.0
# 283             3.6            5.0          29.80                0.0
# 284             5.8            7.8          29.80                0.0
# 285             3.7            5.2          29.80                0.0
#
#      precip_accum_in  uv_index  solar_w/m²
# 1               0.00       0.0         0.0
# 2               0.00       0.0         0.0
# 3               0.00       0.0         0.0
# 4               0.00       0.0         0.0
# 5               0.00       0.0         0.0
# ..               ...       ...         ...
# 281             0.01       0.0         0.0
# 282             0.01       0.0         0.0
# 283             0.01       0.0         0.0
# 284             0.01       0.0         0.0
# 285             0.01       0.0         0.0
#
# [285 rows x 12 columns]
#
#
#          Time Temperature Dew Point Humidity Wind    Speed     Gust  Pressure  \
# 0         NaN         NaN       NaN      NaN  NaN      NaN      NaN       NaN
# 1    00:04:00     52.8 °F   48.5 °F     85 %  NNE  4.6 mph  6.1 mph  29.80 in
# 2    00:09:00     52.7 °F   48.4 °F     85 %   NE  4.4 mph  6.3 mph  29.80 in
# 3    00:14:00     52.8 °F   48.5 °F     85 %   NE  4.8 mph  6.6 mph  29.81 in
# 4    00:19:00     52.7 °F   48.4 °F     85 %   NE  4.2 mph  5.9 mph  29.80 in
# ..        ...         ...       ...      ...  ...      ...      ...       ...
# 280  23:39:00     41.7 °F   40.3 °F     95 %  WNW  0.0 mph  0.0 mph  29.95 in
# 281  23:44:00     41.5 °F   40.1 °F     95 %  WNW  0.0 mph  0.0 mph  29.95 in
# 282  23:49:00     41.5 °F   40.1 °F     95 %  WNW  0.0 mph  0.0 mph  29.95 in
# 283  23:54:00     41.4 °F   40.0 °F     95 %  WNW  0.0 mph  0.0 mph  29.95 in
# 284  23:59:00     41.3 °F   39.8 °F     95 %  WNW  0.0 mph  0.0 mph  29.95 in
#
#     Precip. Rate. Precip. Accum.   UV   Solar
# 0             NaN            NaN  NaN     NaN
# 1         0.00 in        0.00 in  0.0  0 w/m²
# 2         0.00 in        0.00 in  0.0  0 w/m²
# 3         0.00 in        0.00 in  0.0  0 w/m²
# 4         0.00 in        0.00 in  0.0  0 w/m²
# ..            ...            ...  ...     ...
# 280       0.00 in        0.00 in  0.0  0 w/m²
# 281       0.00 in        0.00 in  0.0  0 w/m²
# 282       0.00 in        0.00 in  0.0  0 w/m²
# 283       0.00 in        0.00 in  0.0  0 w/m²
# 284       0.00 in        0.00 in  0.0  0 w/m²
#
# [285 rows x 12 columns]
#                datetime  temperature_°F  dew_point_°F  humidity_% wind_dir  \
# 1   2024-10-03 00:04:00            52.8          48.5        85.0      NNE
# 2   2024-10-03 00:09:00            52.7          48.4        85.0       NE
# 3   2024-10-03 00:14:00            52.8          48.5        85.0       NE
# 4   2024-10-03 00:19:00            52.7          48.4        85.0       NE
# 5   2024-10-03 00:24:00            52.7          48.4        85.0      NNE
# ..                  ...             ...           ...         ...      ...
# 280 2024-10-03 23:39:00            41.7          40.3        95.0      WNW
# 281 2024-10-03 23:44:00            41.5          40.1        95.0      WNW
# 282 2024-10-03 23:49:00            41.5          40.1        95.0      WNW
# 283 2024-10-03 23:54:00            41.4          40.0        95.0      WNW
# 284 2024-10-03 23:59:00            41.3          39.8        95.0      WNW
#
#      wind_speed_mph  wind_gust_mph  pressure_inHg  precip_rate_in/hr  \
# 1               4.6            6.1          29.80                0.0
# 2               4.4            6.3          29.80                0.0
# 3               4.8            6.6          29.81                0.0
# 4               4.2            5.9          29.80                0.0
# 5               4.3            6.1          29.80                0.0
# ..              ...            ...            ...                ...
# 280             0.0            0.0          29.95                0.0
# 281             0.0            0.0          29.95                0.0
# 282             0.0            0.0          29.95                0.0
# 283             0.0            0.0          29.95                0.0
# 284             0.0            0.0          29.95                0.0
#
#      precip_accum_in  uv_index  solar_w/m²
# 1                0.0       0.0         0.0
# 2                0.0       0.0         0.0
# 3                0.0       0.0         0.0
# 4                0.0       0.0         0.0
# 5                0.0       0.0         0.0
# ..               ...       ...         ...
# 280              0.0       0.0         0.0
# 281              0.0       0.0         0.0
# 282              0.0       0.0         0.0
# 283              0.0       0.0         0.0
# 284              0.0       0.0         0.0
#
# [284 rows x 12 columns]
#
#
#          Time Temperature Dew Point Humidity Wind    Speed     Gust  Pressure  \
# 0         NaN         NaN       NaN      NaN  NaN      NaN      NaN       NaN
# 1    00:04:00     41.0 °F   39.6 °F     95 %  WNW  0.0 mph  0.0 mph  29.95 in
# 2    00:09:00     40.9 °F   39.5 °F     95 %  WNW  0.0 mph  0.0 mph  29.96 in
# 3    00:14:00     41.3 °F   39.8 °F     95 %  WNW  0.0 mph  0.0 mph  29.96 in
# 4    00:19:00     41.3 °F   39.8 °F     95 %  WNW  0.0 mph  0.0 mph  29.96 in
# ..        ...         ...       ...      ...  ...      ...      ...       ...
# 284  23:39:00     42.9 °F   42.0 °F     96 %  SSW  0.0 mph  0.0 mph  29.94 in
# 285  23:44:00     42.9 °F   41.7 °F     96 %  SSW  0.0 mph  0.0 mph  29.94 in
# 286  23:49:00     42.4 °F   40.9 °F     95 %  SSW  0.0 mph  0.0 mph  29.95 in
# 287  23:54:00     42.0 °F   40.5 °F     95 %  SSW  0.0 mph  0.0 mph  29.94 in
# 288  23:59:00     41.4 °F   40.1 °F     95 %  SSW  0.0 mph  0.0 mph  29.94 in
#
#     Precip. Rate. Precip. Accum.   UV   Solar
# 0             NaN            NaN  NaN     NaN
# 1         0.00 in        0.00 in  0.0  0 w/m²
# 2         0.00 in        0.00 in  0.0  0 w/m²
# 3         0.00 in        0.00 in  0.0  0 w/m²
# 4         0.00 in        0.00 in  0.0  0 w/m²
# ..            ...            ...  ...     ...
# 284       0.00 in        0.00 in  0.0  0 w/m²
# 285       0.00 in        0.00 in  0.0  0 w/m²
# 286       0.00 in        0.00 in  0.0  0 w/m²
# 287       0.00 in        0.00 in  0.0  0 w/m²
# 288       0.00 in        0.00 in  0.0  0 w/m²
#
# [289 rows x 12 columns]
#                datetime  temperature_°F  dew_point_°F  humidity_% wind_dir  \
# 1   2024-10-04 00:04:00            41.0          39.6        95.0      WNW
# 2   2024-10-04 00:09:00            40.9          39.5        95.0      WNW
# 3   2024-10-04 00:14:00            41.3          39.8        95.0      WNW
# 4   2024-10-04 00:19:00            41.3          39.8        95.0      WNW
# 5   2024-10-04 00:24:00            41.2          39.7        95.0      WNW
# ..                  ...             ...           ...         ...      ...
# 284 2024-10-04 23:39:00            42.9          42.0        96.0      SSW
# 285 2024-10-04 23:44:00            42.9          41.7        96.0      SSW
# 286 2024-10-04 23:49:00            42.4          40.9        95.0      SSW
# 287 2024-10-04 23:54:00            42.0          40.5        95.0      SSW
# 288 2024-10-04 23:59:00            41.4          40.1        95.0      SSW
#
#      wind_speed_mph  wind_gust_mph  pressure_inHg  precip_rate_in/hr  \
# 1               0.0            0.0          29.95                0.0
# 2               0.0            0.0          29.96                0.0
# 3               0.0            0.0          29.96                0.0
# 4               0.0            0.0          29.96                0.0
# 5               0.0            0.0          29.96                0.0
# ..              ...            ...            ...                ...
# 284             0.0            0.0          29.94                0.0
# 285             0.0            0.0          29.94                0.0
# 286             0.0            0.0          29.95                0.0
# 287             0.0            0.0          29.94                0.0
# 288             0.0            0.0          29.94                0.0
#
#      precip_accum_in  uv_index  solar_w/m²
# 1                0.0       0.0         0.0
# 2                0.0       0.0         0.0
# 3                0.0       0.0         0.0
# 4                0.0       0.0         0.0
# 5                0.0       0.0         0.0
# ..               ...       ...         ...
# 284              0.0       0.0         0.0
# 285              0.0       0.0         0.0
# 286              0.0       0.0         0.0
# 287              0.0       0.0         0.0
# 288              0.0       0.0         0.0
#
# [288 rows x 12 columns]
#
#
#          Time Temperature Dew Point Humidity   Wind    Speed     Gust  \
# 0         NaN         NaN       NaN      NaN    NaN      NaN      NaN
# 1    00:04:00     41.7 °F   40.8 °F     96 %    SSW  0.0 mph  0.0 mph
# 2    00:09:00     42.2 °F   41.3 °F     96 %    SSW  0.0 mph  0.0 mph
# 3    00:14:00     42.1 °F   41.2 °F     96 %    SSW  0.0 mph  0.0 mph
# 4    00:19:00     42.4 °F   41.5 °F     96 %    SSW  0.0 mph  0.0 mph
# ..        ...         ...       ...      ...    ...      ...      ...
# 284  23:39:00     48.2 °F   43.5 °F     84 %  South  1.4 mph  2.1 mph
# 285  23:44:00     48.0 °F   43.3 °F     84 %    SSW  1.6 mph  2.2 mph
# 286  23:49:00     48.0 °F   43.3 °F     84 %  South  1.9 mph  2.6 mph
# 287  23:54:00     47.8 °F   43.4 °F     85 %  South  1.7 mph  2.3 mph
# 288  23:59:00     47.7 °F   43.3 °F     85 %  South  1.8 mph  2.5 mph
#
#      Pressure Precip. Rate. Precip. Accum.   UV   Solar
# 0         NaN           NaN            NaN  NaN     NaN
# 1    29.94 in       0.00 in        0.00 in  0.0  0 w/m²
# 2    29.94 in       0.00 in        0.00 in  0.0  0 w/m²
# 3    29.94 in       0.00 in        0.00 in  0.0  0 w/m²
# 4    29.94 in       0.00 in        0.00 in  0.0  0 w/m²
# ..        ...           ...            ...  ...     ...
# 284  29.68 in       0.00 in        0.01 in  0.0  0 w/m²
# 285  29.68 in       0.00 in        0.01 in  0.0  0 w/m²
# 286  29.68 in       0.00 in        0.01 in  0.0  0 w/m²
# 287  29.68 in       0.00 in        0.01 in  0.0  0 w/m²
# 288  29.68 in       0.00 in        0.01 in  0.0  0 w/m²
#
# [289 rows x 12 columns]
#                datetime  temperature_°F  dew_point_°F  humidity_% wind_dir  \
# 1   2024-10-05 00:04:00            41.7          40.8        96.0      SSW
# 2   2024-10-05 00:09:00            42.2          41.3        96.0      SSW
# 3   2024-10-05 00:14:00            42.1          41.2        96.0      SSW
# 4   2024-10-05 00:19:00            42.4          41.5        96.0      SSW
# 5   2024-10-05 00:24:00            42.5          41.6        96.0      SSW
# ..                  ...             ...           ...         ...      ...
# 284 2024-10-05 23:39:00            48.2          43.5        84.0    South
# 285 2024-10-05 23:44:00            48.0          43.3        84.0      SSW
# 286 2024-10-05 23:49:00            48.0          43.3        84.0    South
# 287 2024-10-05 23:54:00            47.8          43.4        85.0    South
# 288 2024-10-05 23:59:00            47.7          43.3        85.0    South
#
#      wind_speed_mph  wind_gust_mph  pressure_inHg  precip_rate_in/hr  \
# 1               0.0            0.0          29.94                0.0
# 2               0.0            0.0          29.94                0.0
# 3               0.0            0.0          29.94                0.0
# 4               0.0            0.0          29.94                0.0
# 5               0.0            0.0          29.94                0.0
# ..              ...            ...            ...                ...
# 284             1.4            2.1          29.68                0.0
# 285             1.6            2.2          29.68                0.0
# 286             1.9            2.6          29.68                0.0
# 287             1.7            2.3          29.68                0.0
# 288             1.8            2.5          29.68                0.0
#
#      precip_accum_in  uv_index  solar_w/m²
# 1               0.00       0.0         0.0
# 2               0.00       0.0         0.0
# 3               0.00       0.0         0.0
# 4               0.00       0.0         0.0
# 5               0.00       0.0         0.0
# ..               ...       ...         ...
# 284             0.01       0.0         0.0
# 285             0.01       0.0         0.0
# 286             0.01       0.0         0.0
# 287             0.01       0.0         0.0
# 288             0.01       0.0         0.0
#
# [288 rows x 12 columns]
#
#
#          Time Temperature Dew Point Humidity   Wind    Speed     Gust  \
# 0         NaN         NaN       NaN      NaN    NaN      NaN      NaN
# 1    00:04:00     47.5 °F   43.3 °F     85 %  South  1.5 mph  2.3 mph
# 2    00:09:00     47.3 °F   43.3 °F     86 %  South  2.2 mph  3.1 mph
# 3    00:14:00     47.3 °F   43.3 °F     86 %  South  1.9 mph  2.6 mph
# 4    00:19:00     47.2 °F   43.3 °F     86 %  South  1.5 mph  2.3 mph
# ..        ...         ...       ...      ...    ...      ...      ...
# 284  23:39:00     57.5 °F   56.4 °F     96 %     SW  1.8 mph  2.9 mph
# 285  23:44:00     57.6 °F   56.5 °F     96 %     SW  2.2 mph  3.2 mph
# 286  23:49:00     57.6 °F   56.5 °F     96 %     SW  1.8 mph  2.7 mph
# 287  23:54:00     57.6 °F   56.5 °F     96 %    SSW  2.4 mph  3.8 mph
# 288  23:59:00     57.7 °F   56.7 °F     96 %    SSW  2.0 mph  3.2 mph
#
#      Pressure Precip. Rate. Precip. Accum.   UV   Solar
# 0         NaN           NaN            NaN  NaN     NaN
# 1    29.68 in       0.00 in        0.00 in  0.0  0 w/m²
# 2    29.67 in       0.00 in        0.00 in  0.0  0 w/m²
# 3    29.67 in       0.00 in        0.00 in  0.0  0 w/m²
# 4    29.67 in       0.00 in        0.00 in  0.0  0 w/m²
# ..        ...           ...            ...  ...     ...
# 284  29.28 in       0.00 in        0.09 in  0.0  0 w/m²
# 285  29.27 in       0.00 in        0.09 in  0.0  0 w/m²
# 286  29.27 in       0.00 in        0.09 in  0.0  0 w/m²
# 287  29.28 in       0.00 in        0.09 in  0.0  0 w/m²
# 288  29.28 in       0.00 in        0.09 in  0.0  0 w/m²
#
# [289 rows x 12 columns]
#                datetime  temperature_°F  dew_point_°F  humidity_% wind_dir  \
# 1   2024-10-06 00:04:00            47.5          43.3        85.0    South
# 2   2024-10-06 00:09:00            47.3          43.3        86.0    South
# 3   2024-10-06 00:14:00            47.3          43.3        86.0    South
# 4   2024-10-06 00:19:00            47.2          43.3        86.0    South
# 5   2024-10-06 00:24:00            47.2          43.3        86.0    South
# ..                  ...             ...           ...         ...      ...
# 284 2024-10-06 23:39:00            57.5          56.4        96.0       SW
# 285 2024-10-06 23:44:00            57.6          56.5        96.0       SW
# 286 2024-10-06 23:49:00            57.6          56.5        96.0       SW
# 287 2024-10-06 23:54:00            57.6          56.5        96.0      SSW
# 288 2024-10-06 23:59:00            57.7          56.7        96.0      SSW
#
#      wind_speed_mph  wind_gust_mph  pressure_inHg  precip_rate_in/hr  \
# 1               1.5            2.3          29.68                0.0
# 2               2.2            3.1          29.67                0.0
# 3               1.9            2.6          29.67                0.0
# 4               1.5            2.3          29.67                0.0
# 5               1.8            2.6          29.67                0.0
# ..              ...            ...            ...                ...
# 284             1.8            2.9          29.28                0.0
# 285             2.2            3.2          29.27                0.0
# 286             1.8            2.7          29.27                0.0
# 287             2.4            3.8          29.28                0.0
# 288             2.0            3.2          29.28                0.0
#
#      precip_accum_in  uv_index  solar_w/m²
# 1               0.00       0.0         0.0
# 2               0.00       0.0         0.0
# 3               0.00       0.0         0.0
# 4               0.00       0.0         0.0
# 5               0.00       0.0         0.0
# ..               ...       ...         ...
# 284             0.09       0.0         0.0
# 285             0.09       0.0         0.0
# 286             0.09       0.0         0.0
# 287             0.09       0.0         0.0
# 288             0.09       0.0         0.0
#
# [288 rows x 12 columns]
#
#
#          Time Temperature Dew Point Humidity  Wind    Speed     Gust  \
# 0         NaN         NaN       NaN      NaN   NaN      NaN      NaN
# 1    00:04:00     57.7 °F   56.7 °F     96 %    SW  2.4 mph  3.5 mph
# 2    00:09:00     57.7 °F   56.7 °F     96 %    SW  2.0 mph  2.9 mph
# 3    00:14:00     57.8 °F   56.8 °F     96 %   WSW  2.5 mph  3.3 mph
# 4    00:19:00     58.0 °F   56.9 °F     96 %   WSW  3.0 mph  4.0 mph
# ..        ...         ...       ...      ...   ...      ...      ...
# 174  14:29:00     65.2 °F   56.3 °F     73 %   WSW  3.7 mph  4.8 mph
# 175  14:34:00     65.5 °F   56.3 °F     72 %   WSW  3.4 mph  4.2 mph
# 176  14:39:00     65.7 °F   55.5 °F     70 %   WSW  4.3 mph  6.1 mph
# 177  14:44:00     66.4 °F   56.1 °F     70 %  West  2.9 mph  4.1 mph
# 178  14:49:00     66.4 °F   55.7 °F     68 %   WSW  2.7 mph  4.2 mph
#
#      Pressure Precip. Rate. Precip. Accum.   UV       Solar
# 0         NaN           NaN            NaN  NaN         NaN
# 1    29.27 in       0.00 in        0.00 in  0.0      0 w/m²
# 2    29.28 in       0.00 in        0.00 in  0.0      0 w/m²
# 3    29.28 in       0.00 in        0.00 in  0.0      0 w/m²
# 4    29.28 in       0.00 in        0.00 in  0.0      0 w/m²
# ..        ...           ...            ...  ...         ...
# 174  29.37 in       0.00 in        0.01 in  4.0  414.8 w/m²
# 175  29.36 in       0.00 in        0.01 in  4.0  416.6 w/m²
# 176  29.36 in       0.00 in        0.01 in  3.0  338.5 w/m²
# 177  29.36 in       0.00 in        0.01 in  3.0  349.6 w/m²
# 178  29.36 in       0.00 in        0.01 in  3.0  345.7 w/m²
#
# [179 rows x 12 columns]

# %%
# Display unique values for each column
# for col in final_df.columns:
#    unique_values = final_df[col].unique()
#    print(f"Column: {col}")
#    print(f"Unique Values: {unique_values[:100]}")  # Display only the first 10 unique values
#    print("-" * 50)

# %%
final_df
# Out:
#                 datetime  temperature_°F  dew_point_°F  humidity_% wind_dir  \
# 0    2024-10-01 00:04:00            56.8          53.1        87.0      WSW
# 1    2024-10-01 00:09:00            56.8          52.9        87.0      WSW
# 2    2024-10-01 00:14:00            57.0          52.8        86.0     West
# 3    2024-10-01 00:19:00            57.2          52.7        85.0      WSW
# 4    2024-10-01 00:24:00            57.2          52.7        85.0      WSW
# ...                  ...             ...           ...         ...      ...
# 1894 2024-10-07 14:29:00            65.2          56.3        73.0      WSW
# 1895 2024-10-07 14:34:00            65.5          56.3        72.0      WSW
# 1896 2024-10-07 14:39:00            65.7          55.5        70.0      WSW
# 1897 2024-10-07 14:44:00            66.4          56.1        70.0     West
# 1898 2024-10-07 14:49:00            66.4          55.7        68.0      WSW
#
#       wind_speed_mph  wind_gust_mph  pressure_inHg  precip_rate_in/hr  \
# 0                8.2           10.4          29.48                0.0
# 1                7.9            9.8          29.47                0.0
# 2               10.3           12.8          29.47                0.0
# 3                9.7           12.2          29.47                0.0
# 4                9.7           11.9          29.47                0.0
# ...              ...            ...            ...                ...
# 1894             3.7            4.8          29.37                0.0
# 1895             3.4            4.2          29.36                0.0
# 1896             4.3            6.1          29.36                0.0
# 1897             2.9            4.1          29.36                0.0
# 1898             2.7            4.2          29.36                0.0
#
#       precip_accum_in  uv_index  solar_w/m²
# 0                0.00       0.0         0.0
# 1                0.00       0.0         0.0
# 2                0.00       0.0         0.0
# 3                0.00       0.0         0.0
# 4                0.00       0.0         0.0
# ...               ...       ...         ...
# 1894             0.01       4.0       414.8
# 1895             0.01       4.0       416.6
# 1896             0.01       3.0       338.5
# 1897             0.01       3.0       349.6
# 1898             0.01       3.0       345.7
#
# [1899 rows x 12 columns]

# %%
def convertToMetric(df):
    """
    Convert to metric and to other small ajustements for all data to be formated the same way
    """
    df = df.copy() 
    	
    df['dew_point_°C'] = ((df['dew_point_°F'] - 32) * 5/9).round(1)
    df['temperature_°C'] = ((df['temperature_°F'] - 32) * 5/9).round(1)
    df['wind_speed_kph'] = (df['wind_speed_mph'] * 1.60934).round(1)
    df['wind_gust_kph'] = (df['wind_gust_mph'] * 1.60934).round(1)
    df['pressure_hPa'] = (df['pressure_inHg'] * 33.8639).round(1)
    df['precip_rate_mm/hr'] = (df['precip_rate_in/hr'] * 25.4).round(1)
    df['precip_accum_mm'] = (df['precip_accum_in'] * 25.4).round(1)
    df['temperature_°C'] = ((df['temperature_°F'] - 32) * 5/9).round(1)

    df['humidity_%'] = df['humidity_%'].astype(int)

    df.drop(columns=['temperature_°F', 'wind_speed_mph', 'wind_gust_mph', 'pressure_inHg', 
                     'precip_rate_in/hr', 'precip_accum_in', 'dew_point_°F'], inplace=True)
    return df

# %%
final_df2 = convertToMetric(final_df)

# %%
final_df2["precip_rate_mm/hr"].unique()
# Out:
# array([0. , 1.8, 1.3, 3. , 7.9, 6.1, 8.9, 4.8])

# %%
final_df2["precip_accum_mm"].unique()
# Out:
# array([0. , 0.3, 0.5, 0.8, 1. , 1.3, 1.5, 1.8, 3. , 3.6, 3.8, 4.1, 4.3,
#        4.6, 2.3])

# %%
final_df2["wind_dir"].unique()
# Out:
# array(['WSW', 'West', 'SW', 'SSW', 'South', 'SSE', 'East', 'SE', 'WNW',
#        'ESE', 'ENE', 'NE', 'NNE', 'North', 'NNW', nan, 'NW'], dtype=object)

# %%
final_df2
# Out:
#                 datetime  humidity_% wind_dir  uv_index  solar_w/m²  \
# 0    2024-10-01 00:04:00          87      WSW       0.0         0.0
# 1    2024-10-01 00:09:00          87      WSW       0.0         0.0
# 2    2024-10-01 00:14:00          86     West       0.0         0.0
# 3    2024-10-01 00:19:00          85      WSW       0.0         0.0
# 4    2024-10-01 00:24:00          85      WSW       0.0         0.0
# ...                  ...         ...      ...       ...         ...
# 1894 2024-10-07 14:29:00          73      WSW       4.0       414.8
# 1895 2024-10-07 14:34:00          72      WSW       4.0       416.6
# 1896 2024-10-07 14:39:00          70      WSW       3.0       338.5
# 1897 2024-10-07 14:44:00          70     West       3.0       349.6
# 1898 2024-10-07 14:49:00          68      WSW       3.0       345.7
#
#       dew_point_°C  temperature_°C  wind_speed_kph  wind_gust_kph  \
# 0             11.7            13.8            13.2           16.7
# 1             11.6            13.8            12.7           15.8
# 2             11.6            13.9            16.6           20.6
# 3             11.5            14.0            15.6           19.6
# 4             11.5            14.0            15.6           19.2
# ...            ...             ...             ...            ...
# 1894          13.5            18.4             6.0            7.7
# 1895          13.5            18.6             5.5            6.8
# 1896          13.1            18.7             6.9            9.8
# 1897          13.4            19.1             4.7            6.6
# 1898          13.2            19.1             4.3            6.8
#
#       pressure_hPa  precip_rate_mm/hr  precip_accum_mm
# 0            998.3                0.0              0.0
# 1            998.0                0.0              0.0
# 2            998.0                0.0              0.0
# 3            998.0                0.0              0.0
# 4            998.0                0.0              0.0
# ...            ...                ...              ...
# 1894         994.6                0.0              0.3
# 1895         994.2                0.0              0.3
# 1896         994.2                0.0              0.3
# 1897         994.2                0.0              0.3
# 1898         994.2                0.0              0.3
#
# [1899 rows x 12 columns]

# %%
# MongoDB setup
client = MongoClient("mongodb://localhost:27017/")
db = client["weather_data2"]
collection = db["weather_station2"]

# %%
collection.insert_many(final_df2.to_dict(orient='records'))

print("Data successfully inserted into MongoDB!")
# Out:
# Data successfully inserted into MongoDB!
