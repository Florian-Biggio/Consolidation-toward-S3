# %%
import sys
import boto3
import json
import pandas as pd
from io import BytesIO
import argparse
import logging
from pymongo import MongoClient, errors
from bson import ObjectId
import hashlib
from datetime import datetime
import statistics
import os

# %%
# Function to load the secrets from the local file
def load_secrets(file_path):
    with open(file_path, 'r') as file:
        return json.load(file)
secrets = load_secrets('secrets.json')

aws_access_key_id = secrets['AWS_ACCESS_KEY_ID']
aws_secret_access_key = secrets['AWS_SECRET_ACCESS_KEY']
aws_region = secrets['AWS_REGION']

# %%
s3 = boto3.client('s3', 
                  aws_access_key_id=aws_access_key_id, 
                  aws_secret_access_key=aws_secret_access_key, 
                  region_name=aws_region)

# %%
# Delete if not in Jupyter Notebook
if 'ipykernel' in sys.modules:
    sys.argv = ['jsonl.py', 'InfoClimat']  


parser = argparse.ArgumentParser(description="Process an Excel file")
parser.add_argument(
    'file',
    default='InfoClimat',
    help='The name of the station to process. Only accepts InfoClimat'
)

parser.add_argument(
    "--mongodb_address", 
    default="mongodb://localhost:27017/", 
    help="The MongoDB address (default: mongodb://localhost:27017/)"
)

def upper_case(string):
    return string.upper()
parser.add_argument(
    "-v", "--verbosity",
    type=upper_case,
    default="INFO", 
    choices=["DEBUG", "INFO", "WARNING", "ERROR", "CRITICAL"],
    help="Set the logging verbosity level (default: INFO)"
)
args = parser.parse_args()

# %%
log_level = getattr(logging, args.verbosity)
logging.basicConfig(level=log_level)
logger = logging.getLogger(__name__)

# %%
mongodb_address = args.mongodb_address
# After parsing arguments
logger.info(f"Station: {args.file}")  
logger.info(f"MongoDB adress: {mongodb_address}")  # Debug lines to check the parsed arguments
# Out:
# INFO:__main__:Station: InfoClimat
# INFO:__main__:MongoDB adress: mongodb://localhost:27017/

# %%
if not args.file:
    args.file = ['InfoClimat']

if args.file == 'InfoClimat':
    file_key = "greencoop-airbyte/Stations_meteorologiques_du_reseau_InfoClimat_(Bergues,_Hazebrouck,_Armentieres,_Lille-Lesquin)/2025_03_14_1741977939508_0.jsonl"

# %%
bucket_name = 'greencoop-airbyte'
s3_object = s3.get_object(Bucket=bucket_name, Key=file_key)
file_content = s3_object['Body'].read().decode('utf-8')

# %%
# Read the JSONL file from S3
response = s3.get_object(Bucket=bucket_name, Key=file_key)
content = response["Body"].read().decode("utf-8")

# Convert JSONL to Pandas DataFrame
json_list = [json.loads(line) for line in content.splitlines()]
df = pd.DataFrame(json_list)

# Show first rows
df.head()
# Out:
#                         _airbyte_raw_id  _airbyte_extracted_at  \
# 0  5e7a90f2-1e3e-42a6-8c76-ee59f1a8f45b          1741977942000
#
#                    _airbyte_meta  _airbyte_generation_id  \
# 0  {'sync_id': 1, 'changes': []}                       1
#
#                                        _airbyte_data
# 0  {'status': 'OK', 'errors': [], 'data': [], 'st...

# %%
import pandas as pd
from pandas import json_normalize

# Assuming `df_clean` is the output of json_normalize
df_clean = pd.json_normalize(df["_airbyte_data"])

# Expand the 'stations' field
stations_df = pd.json_normalize(df_clean["stations"].explode())

# Expand the 'hourly' fields
hourly_dfs = {}
hourly_cols = [col for col in df_clean.columns if col.startswith("hourly.")]
for col in hourly_cols:
    hourly_dfs[col] = pd.json_normalize(df_clean[col].explode())

# Display the extracted DataFrames
print("Stations Data:")
print(stations_df.head())

for col, hourly_df in hourly_dfs.items():
    print(f"\nHourly Data ({col}):")
    print(hourly_df.head())
# Out:
# Stations Data:
#            id           name  latitude  longitude  elevation    type  \
# 0       00052    Armentières    50.689      2.877         16  static
# 1       000R5        Bergues    50.968      2.441         17  static
# 2       07015  Lille-Lesquin    50.575      3.092         47   synop
# 3  STATIC0010     Hazebrouck    50.734      2.545         31  static
#
#        license.license                                        license.url  \
# 0                CC BY    https://creativecommons.org/licenses/by/2.0/fr/
# 1                CC BY    https://creativecommons.org/licenses/by/2.0/fr/
# 2  Etalab Open License  https://www.etalab.gouv.fr/licence-ouverte-ope...
# 3                CC BY    https://creativecommons.org/licenses/by/2.0/fr/
#
#                    license.source  \
# 0                   infoclimat.fr
# 1                   infoclimat.fr
# 2  Meteo-France via infoclimat.fr
# 3                   infoclimat.fr
#
#                                  license.metadonnees
# 0  https://www.infoclimat.fr/stations/metadonnees...
# 1  https://www.infoclimat.fr/stations/metadonnees...
# 2  https://donneespubliques.meteofrance.fr/metado...
# 3  https://www.infoclimat.fr/stations/metadonnees...
#
# Hourly Data (hourly.07015):
#   id_station               dh_utc temperature pression humidite  \
# 0      07015  2024-10-05 00:00:00         7.6   1020.7       89
# 1      07015  2024-10-05 01:00:00         7.5   1020.6       92
# 2      07015  2024-10-05 02:00:00         7.4   1020.3       93
# 3      07015  2024-10-05 03:00:00         6.2   1020.1       95
# 4      07015  2024-10-05 04:00:00         5.5   1019.9       96
#
#   point_de_rosee visibilite vent_moyen vent_rafales vent_direction pluie_3h  \
# 0            5.9       6000        3.6          7.2             90        0
# 1            6.3       7000        3.6          7.2             30     None
# 2            6.3       4400        7.2          7.2             40     None
# 3            5.5       2500        3.6          7.2             60        0
# 4            4.9        500        3.6          3.6             90     None
#
#   pluie_1h neige_au_sol nebulosite temps_omm
# 0        0         None                 None
# 1        0         None                 None
# 2        0         None                   10
# 3        0         None                   10
# 4        0         None                   44
#
# Hourly Data (hourly.00052):
#   id_station               dh_utc temperature pression humidite  \
# 0      00052  2024-10-05 00:00:00         6.4   1019.1       95
# 1      00052  2024-10-05 00:10:00         6.3   1019.1       95
# 2      00052  2024-10-05 00:20:00         6.3     1019       96
# 3      00052  2024-10-05 00:30:00         6.4     1019       96
# 4      00052  2024-10-05 00:40:00         6.3     1019       95
#
#   point_de_rosee vent_moyen vent_rafales vent_direction pluie_3h pluie_1h
# 0            5.6          0         None            134     None        0
# 1            5.6          0         None            134     None     None
# 2            5.6          0         None            134     None     None
# 3            6.1          0         None            134     None     None
# 4            5.6          0         None            134     None     None
#
# Hourly Data (hourly.000R5):
#   id_station               dh_utc temperature pression humidite  \
# 0      000R5  2024-10-05 00:00:00         8.4   1019.3       86
# 1      000R5  2024-10-05 00:10:00         8.6   1019.4       86
# 2      000R5  2024-10-05 00:20:00         8.6   1019.3       85
# 3      000R5  2024-10-05 00:30:00         8.5   1019.3       86
# 4      000R5  2024-10-05 00:40:00         8.4   1019.3       86
#
#   point_de_rosee vent_moyen vent_rafales vent_direction pluie_3h pluie_1h
# 0            6.2        1.4         None            113        0        0
# 1            6.3        1.6         None            113     None     None
# 2            6.2        0.8         None            113     None     None
# 3            6.3        0.3         None            113     None     None
# 4            6.2        2.1         None            113     None     None
#
# Hourly Data (hourly.STATIC0010):
#    id_station               dh_utc temperature pression humidite  \
# 0  STATIC0010  2024-10-05 00:00:00         4.7   1020.6       97
# 1  STATIC0010  2024-10-05 00:10:00         4.7   1020.7       97
# 2  STATIC0010  2024-10-05 00:20:00         4.6   1020.6       97
# 3  STATIC0010  2024-10-05 00:30:00         4.5   1020.6       97
# 4  STATIC0010  2024-10-05 00:40:00         4.4   1020.5       97
#
#   point_de_rosee vent_moyen vent_rafales vent_direction pluie_3h pluie_1h
# 0            4.2          0         None              0     None        0
# 1            4.2          0         None              0     None     None
# 2            4.1          0         None              0     None     None
# 3            4.1          0         None              0     None     None
# 4              4          0         None              0     None     None
#
# Hourly Data (hourly._params):
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
data_to_insert = df_clean.to_dict(orient="records")
data_to_insert[0].keys()
# Out:
# dict_keys(['status', 'errors', 'data', 'stations', 'metadata.temperature', 'metadata.pression', 'metadata.humidite', 'metadata.point_de_rosee', 'metadata.visibilite', 'metadata.vent_moyen', 'metadata.vent_rafales', 'metadata.vent_direction', 'metadata.pluie_3h', 'metadata.pluie_1h', 'metadata.neige_au_sol', 'metadata.nebulosite', 'metadata.temps_omm', 'hourly.07015', 'hourly.00052', 'hourly.000R5', 'hourly.STATIC0010', 'hourly._params'])

# %%
data_to_insert[0]
# Out:
# {'status': 'OK',
#  'errors': [],
#  'data': [],
#  'stations': [{'id': '00052',
#    'name': 'Armentières',
#    'latitude': 50.689,
#    'longitude': 2.877,
#    'elevation': 16,
#    'type': 'static',
#    'license': {'license': 'CC BY',
#     'url': 'https://creativecommons.org/licenses/by/2.0/fr/',
#     'source': 'infoclimat.fr',
#     'metadonnees': 'https://www.infoclimat.fr/stations/metadonnees.php?id=00052'}},
#   {'id': '000R5',
#    'name': 'Bergues',
#    'latitude': 50.968,
#    'longitude': 2.441,
#    'elevation': 17,
#    'type': 'static',
#    'license': {'license': 'CC BY',
#     'url': 'https://creativecommons.org/licenses/by/2.0/fr/',
#     'source': 'infoclimat.fr',
#     'metadonnees': 'https://www.infoclimat.fr/stations/metadonnees.php?id=000R5'}},
#   {'id': '07015',
#    'name': 'Lille-Lesquin',
#    'latitude': 50.575,
#    'longitude': 3.092,
#    'elevation': 47,
#    'type': 'synop',
#    'license': {'license': 'Etalab Open License',
#     'url': 'https://www.etalab.gouv.fr/licence-ouverte-open-licence',
#     'source': 'Meteo-France via infoclimat.fr',
#     'metadonnees': 'https://donneespubliques.meteofrance.fr/metadonnees_publiques/fiches/fiche_59343001.pdf'}},
#   {'id': 'STATIC0010',
#    'name': 'Hazebrouck',
#    'latitude': 50.734,
#    'longitude': 2.545,
#    'elevation': 31,
#    'type': 'static',
#    'license': {'license': 'CC BY',
#     'url': 'https://creativecommons.org/licenses/by/2.0/fr/',
#     'source': 'infoclimat.fr',
#     'metadonnees': 'https://www.infoclimat.fr/stations/metadonnees.php?id=STATIC0010'}}],
#  'metadata.temperature': 'temperature,degC',
#  'metadata.pression': 'mean sea level pressure,hPa',
#  'metadata.humidite': 'relative humidity,%',
#  'metadata.point_de_rosee': 'dewpoint,degC',
#  'metadata.visibilite': 'horizontal visibility,m',
#  'metadata.vent_moyen': 'mean wind speed,km/h',
#  'metadata.vent_rafales': 'wind gust,km/h',
#  'metadata.vent_direction': 'wind direction,deg',
#  'metadata.pluie_3h': 'precipitation over 3h,mm',
#  'metadata.pluie_1h': 'precipitation over 1h,mm',
#  'metadata.neige_au_sol': 'snow depth,cm',
#  'metadata.nebulosite': 'Ncloud cover,octats',
#  'metadata.temps_omm': 'present weather,http://www.infoclimat.fr/stations-meteo/ww.php',
#  'hourly.07015': [{'id_station': '07015',
#    'dh_utc': '2024-10-05 00:00:00',
#    'temperature': '7.6',
#    'pression': '1020.7',
#    'humidite': '89',
#    'point_de_rosee': '5.9',
#    'visibilite': '6000',
#    'vent_moyen': '3.6',
#    'vent_rafales': '7.2',
#    'vent_direction': '90',
#    'pluie_3h': '0',
#    'pluie_1h': '0',
#    'neige_au_sol': None,
#    'nebulosite': '',
#    'temps_omm': None},
#   {'id_station': '07015',
#    'dh_utc': '2024-10-05 01:00:00',
#    'temperature': '7.5',
#    'pression': '1020.6',
#    'humidite': '92',
#    'point_de_rosee': '6.3',
#    'visibilite': '7000',
#    'vent_moyen': '3.6',
#    'vent_rafales': '7.2',
#    'vent_direction': '30',
#    'pluie_3h': None,
#    'pluie_1h': '0',
#    'neige_au_sol': None,
#    'nebulosite': '',
#    'temps_omm': None},
#   {'id_station': '07015',
#    'dh_utc': '2024-10-05 02:00:00',
#    'temperature': '7.4',
#    'pression': '1020.3',
#    'humidite': '93',
#    'point_de_rosee': '6.3',
#    'visibilite': '4400',
#    'vent_moyen': '7.2',
#    'vent_rafales': '7.2',
#    'vent_direction': '40',
#    'pluie_3h': None,
#    'pluie_1h': '0',
#    'neige_au_sol': None,
#    'nebulosite': '',
#    'temps_omm': '10'},
#   {'id_station': '07015',
#    'dh_utc': '2024-10-05 03:00:00',
#    'temperature': '6.2',
#    'pression': '1020.1',
#    'humidite': '95',
#    'point_de_rosee': '5.5',
#    'visibilite': '2500',
#    'vent_moyen': '3.6',
#    'vent_rafales': '7.2',
#    'vent_direction': '60',
#    'pluie_3h': '0',
#    'pluie_1h': '0',
#    'neige_au_sol': None,
#    'nebulosite': '',
#    'temps_omm': '10'},
#   {'id_station': '07015',
#    'dh_utc': '2024-10-05 04:00:00',
#    'temperature': '5.5',
#    'pression': '1019.9',
#    'humidite': '96',
#    'point_de_rosee': '4.9',
#    'visibilite': '500',
#    'vent_moyen': '3.6',
#    'vent_rafales': '3.6',
#    'vent_direction': '90',
#    'pluie_3h': None,
#    'pluie_1h': '0',
#    'neige_au_sol': None,
#    'nebulosite': '',
#    'temps_omm': '44'},
#   {'id_station': '07015',
#    'dh_utc': '2024-10-05 05:00:00',
#    'temperature': '5',
#    'pression': '1019.8',
#    'humidite': '98',
#    'point_de_rosee': '4.7',
#    'visibilite': '300',
#    'vent_moyen': '3.6',
#    'vent_rafales': '3.6',
#    'vent_direction': '100',
#    'pluie_3h': None,
#    'pluie_1h': '0',
#    'neige_au_sol': None,
#    'nebulosite': '',
#    'temps_omm': '44'},
#   {'id_station': '07015',
#    'dh_utc': '2024-10-05 06:00:00',
#    'temperature': '5.1',
#    'pression': '1019.7',
#    'humidite': '100',
#    'point_de_rosee': '5.1',
#    'visibilite': '100',
#    'vent_moyen': '3.6',
#    'vent_rafales': '10.8',
#    'vent_direction': '100',
#    'pluie_3h': '0',
#    'pluie_1h': '0',
#    'neige_au_sol': None,
#    'nebulosite': '8',
#    'temps_omm': '45'},
#   {'id_station': '07015',
#    'dh_utc': '2024-10-05 07:00:00',
#    'temperature': '5.8',
#    'pression': '1019.5',
#    'humidite': '100',
#    'point_de_rosee': '5.8',
#    'visibilite': '700',
#    'vent_moyen': '3.6',
#    'vent_rafales': '10.8',
#    'vent_direction': '90',
#    'pluie_3h': None,
#    'pluie_1h': '0',
#    'neige_au_sol': None,
#    'nebulosite': '',
#    'temps_omm': '44'},
#   {'id_station': '07015',
#    'dh_utc': '2024-10-05 08:00:00',
#    'temperature': '8.2',
#    'pression': '1019.6',
#    'humidite': '98',
#    'point_de_rosee': '7.9',
#    'visibilite': '5000',
#    'vent_moyen': '7.2',
#    'vent_rafales': '10.8',
#    'vent_direction': '120',
#    'pluie_3h': None,
#    'pluie_1h': '0',
#    'neige_au_sol': None,
#    'nebulosite': '',
#    'temps_omm': None},
#   {'id_station': '07015',
#    'dh_utc': '2024-10-05 09:00:00',
#    'temperature': '11.3',
#    'pression': '1019.6',
#    'humidite': '84',
#    'point_de_rosee': '8.7',
#    'visibilite': '6000',
#    'vent_moyen': '7.2',
#    'vent_rafales': '10.8',
#    'vent_direction': '140',
#    'pluie_3h': '0',
#    'pluie_1h': '0',
#    'neige_au_sol': None,
#    'nebulosite': '',
#    'temps_omm': None},
#   {'id_station': '07015',
#    'dh_utc': '2024-10-05 10:00:00',
#    'temperature': '13.8',
#    'pression': '1019.1',
#    'humidite': '72',
#    'point_de_rosee': '8.8',
#    'visibilite': '11000',
#    'vent_moyen': '7.2',
#    'vent_rafales': '10.8',
#    'vent_direction': '140',
#    'pluie_3h': None,
#    'pluie_1h': '0',
#    'neige_au_sol': None,
#    'nebulosite': '',
#    'temps_omm': None},
#   {'id_station': '07015',
#    'dh_utc': '2024-10-05 11:00:00',
#    'temperature': '15.5',
#    'pression': '1018.4',
#    'humidite': '65',
#    'point_de_rosee': '8.9',
#    'visibilite': '26000',
#    'vent_moyen': '7.2',
#    'vent_rafales': '14.4',
#    'vent_direction': '150',
#    'pluie_3h': None,
#    'pluie_1h': '0',
#    'neige_au_sol': None,
#    'nebulosite': '',
#    'temps_omm': None},
#   {'id_station': '07015',
#    'dh_utc': '2024-10-05 12:00:00',
#    'temperature': '16.9',
#    'pression': '1017.4',
#    'humidite': '57',
#    'point_de_rosee': '8.3',
#    'visibilite': '25000',
#    'vent_moyen': '10.8',
#    'vent_rafales': '21.6',
#    'vent_direction': '160',
#    'pluie_3h': '0',
#    'pluie_1h': '0',
#    'neige_au_sol': None,
#    'nebulosite': '',
#    'temps_omm': None},
#   {'id_station': '07015',
#    'dh_utc': '2024-10-05 13:00:00',
#    'temperature': '17.2',
#    'pression': '1016.4',
#    'humidite': '58',
#    'point_de_rosee': '8.9',
#    'visibilite': '25000',
#    'vent_moyen': '10.8',
#    'vent_rafales': '32.4',
#    'vent_direction': '140',
#    'pluie_3h': None,
#    'pluie_1h': '0',
#    'neige_au_sol': None,
#    'nebulosite': '',
#    'temps_omm': None},
#   {'id_station': '07015',
#    'dh_utc': '2024-10-05 14:00:00',
#    'temperature': '16.2',
#    'pression': '1015.9',
#    'humidite': '56',
#    'point_de_rosee': '7.4',
#    'visibilite': '30000',
#    'vent_moyen': '10.8',
#    'vent_rafales': '28.8',
#    'vent_direction': '160',
#    'pluie_3h': None,
#    'pluie_1h': '0',
#    'neige_au_sol': None,
#    'nebulosite': '',
#    'temps_omm': None},
#   {'id_station': '07015',
#    'dh_utc': '2024-10-05 15:00:00',
#    'temperature': '15.8',
#    'pression': '1015.3',
#    'humidite': '58',
#    'point_de_rosee': '7.5',
#    'visibilite': '30000',
#    'vent_moyen': '14.4',
#    'vent_rafales': '21.6',
#    'vent_direction': '90',
#    'pluie_3h': '0',
#    'pluie_1h': '0',
#    'neige_au_sol': None,
#    'nebulosite': '7',
#    'temps_omm': None},
#   {'id_station': '07015',
#    'dh_utc': '2024-10-05 16:00:00',
#    'temperature': '14.9',
#    'pression': '1014.5',
#    'humidite': '61',
#    'point_de_rosee': '7.4',
#    'visibilite': '19000',
#    'vent_moyen': '14.4',
#    'vent_rafales': '21.6',
#    'vent_direction': '100',
#    'pluie_3h': None,
#    'pluie_1h': '0',
#    'neige_au_sol': None,
#    'nebulosite': '',
#    'temps_omm': None},
#   {'id_station': '07015',
#    'dh_utc': '2024-10-05 17:00:00',
#    'temperature': '12.5',
#    'pression': '1013.9',
#    'humidite': '71',
#    'point_de_rosee': '7.4',
#    'visibilite': '40000',
#    'vent_moyen': '10.8',
#    'vent_rafales': '18',
#    'vent_direction': '90',
#    'pluie_3h': None,
#    'pluie_1h': '0',
#    'neige_au_sol': None,
#    'nebulosite': '',
#    'temps_omm': None},
#   {'id_station': '07015',
#    'dh_utc': '2024-10-05 18:00:00',
#    'temperature': '10.9',
#    'pression': '1013.7',
#    'humidite': '78',
#    'point_de_rosee': '7.2',
#    'visibilite': '30000',
#    'vent_moyen': '10.8',
#    'vent_rafales': '14.4',
#    'vent_direction': '90',
#    'pluie_3h': '0',
#    'pluie_1h': '0',
#    'neige_au_sol': None,
#    'nebulosite': '',
#    'temps_omm': None},
#   {'id_station': '07015',
#    'dh_utc': '2024-10-05 19:00:00',
#    'temperature': '10.4',
#    'pression': '1013.3',
#    'humidite': '81',
#    'point_de_rosee': '7.3',
#    'visibilite': '19000',
#    'vent_moyen': '7.2',
#    'vent_rafales': '10.8',
#    'vent_direction': '90',
#    'pluie_3h': None,
#    'pluie_1h': '0',
#    'neige_au_sol': None,
#    'nebulosite': '',
#    'temps_omm': None},
#   {'id_station': '07015',
#    'dh_utc': '2024-10-05 20:00:00',
#    'temperature': '9.2',
#    'pression': '1012.9',
#    'humidite': '85',
#    'point_de_rosee': '6.8',
#    'visibilite': '20000',
#    'vent_moyen': '10.8',
#    'vent_rafales': '18',
#    'vent_direction': '90',
#    'pluie_3h': None,
#    'pluie_1h': '0',
#    'neige_au_sol': None,
#    'nebulosite': '',
#    'temps_omm': None},
#   {'id_station': '07015',
#    'dh_utc': '2024-10-05 21:00:00',
#    'temperature': '8.7',
#    'pression': '1012.4',
#    'humidite': '86',
#    'point_de_rosee': '6.5',
#    'visibilite': '22000',
#    'vent_moyen': '14.4',
#    'vent_rafales': '21.6',
#    'vent_direction': '100',
#    'pluie_3h': '0',
#    'pluie_1h': '0',
#    'neige_au_sol': None,
#    'nebulosite': '',
#    'temps_omm': None},
#   {'id_station': '07015',
#    'dh_utc': '2024-10-05 22:00:00',
#    'temperature': '8.3',
#    'pression': '1012.3',
#    'humidite': '86',
#    'point_de_rosee': '6.1',
#    'visibilite': '26000',
#    'vent_moyen': '7.2',
#    'vent_rafales': '18',
#    'vent_direction': '120',
#    'pluie_3h': None,
#    'pluie_1h': '0',
#    'neige_au_sol': None,
#    'nebulosite': '',
#    'temps_omm': None},
#   {'id_station': '07015',
#    'dh_utc': '2024-10-05 23:00:00',
#    'temperature': '7.6',
#    'pression': '1011.4',
#    'humidite': '88',
#    'point_de_rosee': '5.7',
#    'visibilite': '21000',
#    'vent_moyen': '7.2',
#    'vent_rafales': '14.4',
#    'vent_direction': '120',
#    'pluie_3h': None,
#    'pluie_1h': '0',
#    'neige_au_sol': None,
#    'nebulosite': '',
#    'temps_omm': None},
#   {'id_station': '07015',
#    'dh_utc': '2024-10-06 00:00:00',
#    'temperature': '7.4',
#    'pression': '1010.8',
#    'humidite': '87',
#    'point_de_rosee': '5.4',
#    'visibilite': '21000',
#    'vent_moyen': '10.8',
#    'vent_rafales': '18',
#    'vent_direction': '100',
#    'pluie_3h': '0.2',
#    'pluie_1h': '0.2',
#    'neige_au_sol': None,
#    'nebulosite': '',
#    'temps_omm': None},
#   {'id_station': '07015',
#    'dh_utc': '2024-10-06 01:00:00',
#    'temperature': '7.8',
#    'pression': '1010.2',
#    'humidite': '88',
#    'point_de_rosee': '5.9',
#    'visibilite': '22000',
#    'vent_moyen': '10.8',
#    'vent_rafales': '18',
#    'vent_direction': '120',
#    'pluie_3h': None,
#    'pluie_1h': '0',
#    'neige_au_sol': None,
#    'nebulosite': '',
#    'temps_omm': None},
#   {'id_station': '07015',
#    'dh_utc': '2024-10-06 02:00:00',
#    'temperature': '7.9',
#    'pression': '1009',
#    'humidite': '89',
#    'point_de_rosee': '6.2',
#    'visibilite': '21000',
#    'vent_moyen': '14.4',
#    'vent_rafales': '25.2',
#    'vent_direction': '100',
#    'pluie_3h': None,
#    'pluie_1h': '0',
#    'neige_au_sol': None,
#    'nebulosite': '',
#    'temps_omm': None},
#   {'id_station': '07015',
#    'dh_utc': '2024-10-06 03:00:00',
#    'temperature': '8.2',
#    'pression': '1008.5',
#    'humidite': '89',
#    'point_de_rosee': '6.5',
#    'visibilite': '26000',
#    'vent_moyen': '14.4',
#    'vent_rafales': '25.2',
#    'vent_direction': '110',
#    'pluie_3h': '0',
#    'pluie_1h': '0',
#    'neige_au_sol': None,
#    'nebulosite': '6',
#    'temps_omm': None},
#   {'id_station': '07015',
#    'dh_utc': '2024-10-06 04:00:00',
#    'temperature': '8.2',
#    'pression': '1007.8',
#    'humidite': '89',
#    'point_de_rosee': '6.5',
#    'visibilite': '26000',
#    'vent_moyen': '18',
#    'vent_rafales': '28.8',
#    'vent_direction': '110',
#    'pluie_3h': None,
#    'pluie_1h': '0',
#    'neige_au_sol': None,
#    'nebulosite': '8',
#    'temps_omm': None},
#   {'id_station': '07015',
#    'dh_utc': '2024-10-06 05:00:00',
#    'temperature': '8.4',
#    'pression': '1007.2',
#    'humidite': '89',
#    'point_de_rosee': '6.7',
#    'visibilite': '26000',
#    'vent_moyen': '18',
#    'vent_rafales': '25.2',
#    'vent_direction': '110',
#    'pluie_3h': None,
#    'pluie_1h': '0',
#    'neige_au_sol': None,
#    'nebulosite': '8',
#    'temps_omm': None},
#   {'id_station': '07015',
#    'dh_utc': '2024-10-06 06:00:00',
#    'temperature': '8.8',
#    'pression': '1007',
#    'humidite': '88',
#    'point_de_rosee': '6.9',
#    'visibilite': '27000',
#    'vent_moyen': '21.6',
#    'vent_rafales': '28.8',
#    'vent_direction': '110',
#    'pluie_3h': '0',
#    'pluie_1h': '0',
#    'neige_au_sol': None,
#    'nebulosite': '8',
#    'temps_omm': None},
#   {'id_station': '07015',
#    'dh_utc': '2024-10-06 07:00:00',
#    'temperature': '9.4',
#    'pression': '1006.4',
#    'humidite': '85',
#    'point_de_rosee': '7',
#    'visibilite': '23000',
#    'vent_moyen': '18',
#    'vent_rafales': '32.4',
#    'vent_direction': '90',
#    'pluie_3h': None,
#    'pluie_1h': '0',
#    'neige_au_sol': None,
#    'nebulosite': '8',
#    'temps_omm': None},
#   {'id_station': '07015',
#    'dh_utc': '2024-10-06 08:00:00',
#    'temperature': '9.9',
#    'pression': '1006.2',
#    'humidite': '85',
#    'point_de_rosee': '7.5',
#    'visibilite': '30000',
#    'vent_moyen': '14.4',
#    'vent_rafales': '32.4',
#    'vent_direction': '110',
#    'pluie_3h': None,
#    'pluie_1h': '0',
#    'neige_au_sol': None,
#    'nebulosite': '7',
#    'temps_omm': None},
#   {'id_station': '07015',
#    'dh_utc': '2024-10-06 09:00:00',
#    'temperature': '12',
#    'pression': '1005.3',
#    'humidite': '79',
#    'point_de_rosee': '8.5',
#    'visibilite': '19000',
#    'vent_moyen': '21.6',
#    'vent_rafales': '32.4',
#    'vent_direction': '120',
#    'pluie_3h': '0',
#    'pluie_1h': '0',
#    'neige_au_sol': None,
#    'nebulosite': '8',
#    'temps_omm': None},
#   {'id_station': '07015',
#    'dh_utc': '2024-10-06 10:00:00',
#    'temperature': '13.6',
#    'pression': '1004.8',
#    'humidite': '71',
#    'point_de_rosee': '8.4',
#    'visibilite': '20000',
#    'vent_moyen': '21.6',
#    'vent_rafales': '39.6',
#    'vent_direction': '140',
#    'pluie_3h': None,
#    'pluie_1h': '0',
#    'neige_au_sol': None,
#    'nebulosite': '',
#    'temps_omm': None},
#   {'id_station': '07015',
#    'dh_utc': '2024-10-06 11:00:00',
#    'temperature': '15.4',
#    'pression': '1004',
#    'humidite': '67',
#    'point_de_rosee': '9.3',
#    'visibilite': '16000',
#    'vent_moyen': '25.2',
#    'vent_rafales': '43.2',
#    'vent_direction': '140',
#    'pluie_3h': None,
#    'pluie_1h': '0',
#    'neige_au_sol': None,
#    'nebulosite': '',
#    'temps_omm': None},
#   {'id_station': '07015',
#    'dh_utc': '2024-10-06 12:00:00',
#    'temperature': '15',
#    'pression': '1003.1',
#    'humidite': '69',
#    'point_de_rosee': '9.4',
#    'visibilite': '17000',
#    'vent_moyen': '25.2',
#    'vent_rafales': '39.6',
#    'vent_direction': '140',
#    'pluie_3h': '0',
#    'pluie_1h': '0',
#    'neige_au_sol': None,
#    'nebulosite': '7',
#    'temps_omm': None},
#   {'id_station': '07015',
#    'dh_utc': '2024-10-06 13:00:00',
#    'temperature': '15.3',
#    'pression': '1002.4',
#    'humidite': '69',
#    'point_de_rosee': '9.6',
#    'visibilite': '19000',
#    'vent_moyen': '25.2',
#    'vent_rafales': '36',
#    'vent_direction': '130',
#    'pluie_3h': None,
#    'pluie_1h': '0',
#    'neige_au_sol': None,
#    'nebulosite': '7',
#    'temps_omm': None},
#   {'id_station': '07015',
#    'dh_utc': '2024-10-06 14:00:00',
#    'temperature': '15',
#    'pression': '1002',
#    'humidite': '71',
#    'point_de_rosee': '9.8',
#    'visibilite': '22000',
#    'vent_moyen': '25.2',
#    'vent_rafales': '46.8',
#    'vent_direction': '150',
#    'pluie_3h': None,
#    'pluie_1h': '0',
#    'neige_au_sol': None,
#    'nebulosite': '8',
#    'temps_omm': None},
#   {'id_station': '07015',
#    'dh_utc': '2024-10-06 15:00:00',
#    'temperature': '13.3',
#    'pression': '1002.1',
#    'humidite': '88',
#    'point_de_rosee': '11.4',
#    'visibilite': '3900',
#    'vent_moyen': '21.6',
#    'vent_rafales': '43.2',
#    'vent_direction': '160',
#    'pluie_3h': None,
#    'pluie_1h': '0',
#    'neige_au_sol': None,
#    'nebulosite': '8',
#    'temps_omm': '61'},
#   {'id_station': '07015',
#    'dh_utc': '2024-10-06 16:00:00',
#    'temperature': '13.2',
#    'pression': '1001.7',
#    'humidite': '88',
#    'point_de_rosee': '11.3',
#    'visibilite': '19000',
#    'vent_moyen': '18',
#    'vent_rafales': '32.4',
#    'vent_direction': '150',
#    'pluie_3h': None,
#    'pluie_1h': '0',
#    'neige_au_sol': None,
#    'nebulosite': '8',
#    'temps_omm': None},
#   {'id_station': '07015',
#    'dh_utc': '2024-10-06 17:00:00',
#    'temperature': '13',
#    'pression': '1001.7',
#    'humidite': '95',
#    'point_de_rosee': '12.2',
#    'visibilite': '4600',
#    'vent_moyen': '18',
#    'vent_rafales': '28.8',
#    'vent_direction': '160',
#    'pluie_3h': None,
#    'pluie_1h': '0',
#    'neige_au_sol': None,
#    'nebulosite': '8',
#    'temps_omm': '10'},
#   {'id_station': '07015',
#    'dh_utc': '2024-10-06 18:00:00',
#    'temperature': '13.1',
#    'pression': '1001.3',
#    'humidite': '98',
#    'point_de_rosee': '12.8',
#    'visibilite': '3000',
#    'vent_moyen': '14.4',
#    'vent_rafales': '25.2',
#    'vent_direction': '160',
#    'pluie_3h': None,
#    'pluie_1h': '0',
#    'neige_au_sol': None,
#    'nebulosite': '8',
#    'temps_omm': '10'},
#   {'id_station': '07015',
#    'dh_utc': '2024-10-06 19:00:00',
#    'temperature': '13.5',
#    'pression': '1001',
#    'humidite': '98',
#    'point_de_rosee': '13.2',
#    'visibilite': '15000',
#    'vent_moyen': '14.4',
#    'vent_rafales': '25.2',
#    'vent_direction': '160',
#    'pluie_3h': None,
#    'pluie_1h': '0',
#    'neige_au_sol': None,
#    'nebulosite': '8',
#    'temps_omm': None},
#   {'id_station': '07015',
#    'dh_utc': '2024-10-06 20:00:00',
#    'temperature': '13.9',
#    'pression': '1000.3',
#    'humidite': '97',
#    'point_de_rosee': '13.4',
#    'visibilite': '14000',
#    'vent_moyen': '18',
#    'vent_rafales': '32.4',
#    'vent_direction': '150',
#    'pluie_3h': None,
#    'pluie_1h': '0',
#    'neige_au_sol': None,
#    'nebulosite': '8',
#    'temps_omm': None},
#   {'id_station': '07015',
#    'dh_utc': '2024-10-06 21:00:00',
#    'temperature': '14.4',
#    'pression': '1000',
#    'humidite': '98',
#    'point_de_rosee': '14.1',
#    'visibilite': '14000',
#    'vent_moyen': '18',
#    'vent_rafales': '28.8',
#    'vent_direction': '160',
#    'pluie_3h': '0.2',
#    'pluie_1h': '0.2',
#    'neige_au_sol': None,
#    'nebulosite': '8',
#    'temps_omm': None},
#   {'id_station': '07015',
#    'dh_utc': '2024-10-06 22:00:00',
#    'temperature': '15.1',
#    'pression': '1000',
#    'humidite': '98',
#    'point_de_rosee': '14.8',
#    'visibilite': '14000',
#    'vent_moyen': '18',
#    'vent_rafales': '28.8',
#    'vent_direction': '170',
#    'pluie_3h': None,
#    'pluie_1h': '0',
#    'neige_au_sol': None,
#    'nebulosite': '8',
#    'temps_omm': None},
#   {'id_station': '07015',
#    'dh_utc': '2024-10-06 23:00:00',
#    'temperature': '15.8',
#    'pression': '999.4',
#    'humidite': '95',
#    'point_de_rosee': '15',
#    'visibilite': '30000',
#    'vent_moyen': '25.2',
#    'vent_rafales': '36',
#    'vent_direction': '180',
#    'pluie_3h': None,
#    'pluie_1h': '0.2',
#    'neige_au_sol': None,
#    'nebulosite': '7',
#    'temps_omm': None},
#   {'id_station': '07015',
#    'dh_utc': '2024-10-07 00:00:00',
#    'temperature': '15.3',
#    'pression': '999.5',
#    'humidite': '94',
#    'point_de_rosee': '14.3',
#    'visibilite': '35000',
#    'vent_moyen': '21.6',
#    'vent_rafales': '36',
#    'vent_direction': '190',
#    'pluie_3h': '0.2',
#    'pluie_1h': '0',
#    'neige_au_sol': None,
#    'nebulosite': '',
#    'temps_omm': None},
#   {'id_station': '07015',
#    'dh_utc': '2024-10-07 01:00:00',
#    'temperature': '14.9',
#    'pression': '1000.4',
#    'humidite': '94',
#    'point_de_rosee': '13.9',
#    'visibilite': '35000',
#    'vent_moyen': '18',
#    'vent_rafales': '32.4',
#    'vent_direction': '210',
#    'pluie_3h': None,
#    'pluie_1h': '0',
#    'neige_au_sol': None,
#    'nebulosite': '6',
#    'temps_omm': None},
#   {'id_station': '07015',
#    'dh_utc': '2024-10-07 02:00:00',
#    'temperature': '14.8',
#    'pression': '1001',
#    'humidite': '86',
#    'point_de_rosee': '12.5',
#    'visibilite': '45000',
#    'vent_moyen': '18',
#    'vent_rafales': '36',
#    'vent_direction': '230',
#    'pluie_3h': None,
#    'pluie_1h': '0',
#    'neige_au_sol': None,
#    'nebulosite': '7',
#    'temps_omm': None},
#   {'id_station': '07015',
#    'dh_utc': '2024-10-07 03:00:00',
#    'temperature': '14',
#    'pression': '1001.2',
#    'humidite': '87',
#    'point_de_rosee': '11.9',
#    'visibilite': '40000',
#    'vent_moyen': '14.4',
#    'vent_rafales': '32.4',
#    'vent_direction': '220',
#    'pluie_3h': '0',
#    'pluie_1h': '0',
#    'neige_au_sol': None,
#    'nebulosite': '7',
#    'temps_omm': None},
#   {'id_station': '07015',
#    'dh_utc': '2024-10-07 04:00:00',
#    'temperature': '12.9',
#    'pression': '1001.8',
#    'humidite': '92',
#    'point_de_rosee': '11.6',
#    'visibilite': '35000',
#    'vent_moyen': '14.4',
#    'vent_rafales': '25.2',
#    'vent_direction': '210',
#    'pluie_3h': None,
#    'pluie_1h': '0',
#    'neige_au_sol': None,
#    'nebulosite': '6',
#    'temps_omm': None},
#   {'id_station': '07015',
#    'dh_utc': '2024-10-07 05:00:00',
#    'temperature': '12.3',
#    'pression': '1001.8',
#    'humidite': '92',
#    'point_de_rosee': '11',
#    'visibilite': '35000',
#    'vent_moyen': '14.4',
#    'vent_rafales': '25.2',
#    'vent_direction': '200',
#    'pluie_3h': None,
#    'pluie_1h': '0',
#    'neige_au_sol': None,
#    'nebulosite': '',
#    'temps_omm': None},
#   {'id_station': '07015',
#    'dh_utc': '2024-10-07 06:00:00',
#    'temperature': '11.8',
#    'pression': '1002',
#    'humidite': '94',
#    'point_de_rosee': '10.9',
#    'visibilite': '35000',
#    'vent_moyen': '14.4',
#    'vent_rafales': '18',
#    'vent_direction': '200',
#    'pluie_3h': '0',
#    'pluie_1h': '0',
#    'neige_au_sol': None,
#    'nebulosite': '',
#    'temps_omm': None},
#   {'id_station': '07015',
#    'dh_utc': '2024-10-07 07:00:00',
#    'temperature': '12.7',
#    'pression': '1002.2',
#    'humidite': '93',
#    'point_de_rosee': '11.6',
#    'visibilite': '27000',
#    'vent_moyen': '7.2',
#    'vent_rafales': '21.6',
#    'vent_direction': '170',
#    'pluie_3h': None,
#    'pluie_1h': '0',
#    'neige_au_sol': None,
#    'nebulosite': '',
#    'temps_omm': None},
#   {'id_station': '07015',
#    'dh_utc': '2024-10-07 08:00:00',
#    'temperature': '14.2',
#    'pression': '1002.9',
#    'humidite': '90',
#    'point_de_rosee': '12.6',
#    'visibilite': '19000',
#    'vent_moyen': '14.4',
#    'vent_rafales': '21.6',
#    'vent_direction': '190',
#    'pluie_3h': None,
#    'pluie_1h': '0',
#    'neige_au_sol': None,
#    'nebulosite': '',
#    'temps_omm': None},
#   {'id_station': '07015',
#    'dh_utc': '2024-10-07 09:00:00',
#    'temperature': '15.7',
#    'pression': '1003.5',
#    'humidite': '81',
#    'point_de_rosee': '12.4',
#    'visibilite': '19000',
#    'vent_moyen': '18',
#    'vent_rafales': '32.4',
#    'vent_direction': '200',
#    'pluie_3h': '0',
#    'pluie_1h': '0',
#    'neige_au_sol': None,
#    'nebulosite': '',
#    'temps_omm': None},
#   {'id_station': '07015',
#    'dh_utc': '2024-10-07 10:00:00',
#    'temperature': '16.8',
#    'pression': '1003',
#    'humidite': '75',
#    'point_de_rosee': '12.3',
#    'visibilite': '21000',
#    'vent_moyen': '21.6',
#    'vent_rafales': '32.4',
#    'vent_direction': '180',
#    'pluie_3h': None,
#    'pluie_1h': '0',
#    'neige_au_sol': None,
#    'nebulosite': '',
#    'temps_omm': None},
#   {'id_station': '07015',
#    'dh_utc': '2024-10-07 11:00:00',
#    'temperature': '17.6',
#    'pression': '1003.3',
#    'humidite': '71',
#    'point_de_rosee': '12.3',
#    'visibilite': '19000',
#    'vent_moyen': '18',
#    'vent_rafales': '32.4',
#    'vent_direction': '170',
#    'pluie_3h': None,
#    'pluie_1h': '0',
#    'neige_au_sol': None,
#    'nebulosite': '',
#    'temps_omm': None}],
#  'hourly.00052': [{'id_station': '00052',
#    'dh_utc': '2024-10-05 00:00:00',
#    'temperature': '6.4',
#    'pression': '1019.1',
#    'humidite': '95',
#    'point_de_rosee': '5.6',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '134',
#    'pluie_3h': None,
#    'pluie_1h': '0'},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 00:10:00',
#    'temperature': '6.3',
#    'pression': '1019.1',
#    'humidite': '95',
#    'point_de_rosee': '5.6',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '134',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 00:20:00',
#    'temperature': '6.3',
#    'pression': '1019',
#    'humidite': '96',
#    'point_de_rosee': '5.6',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '134',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 00:30:00',
#    'temperature': '6.4',
#    'pression': '1019',
#    'humidite': '96',
#    'point_de_rosee': '6.1',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '134',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 00:40:00',
#    'temperature': '6.3',
#    'pression': '1019',
#    'humidite': '95',
#    'point_de_rosee': '5.6',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '134',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 00:50:00',
#    'temperature': '6.2',
#    'pression': '1018.9',
#    'humidite': '95',
#    'point_de_rosee': '5.6',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '134',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 01:00:00',
#    'temperature': '6.1',
#    'pression': '1018.9',
#    'humidite': '95',
#    'point_de_rosee': '5.6',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '134',
#    'pluie_3h': None,
#    'pluie_1h': '0'},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 01:10:00',
#    'temperature': '5.8',
#    'pression': '1018.8',
#    'humidite': '95',
#    'point_de_rosee': '5',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '134',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 01:20:00',
#    'temperature': '5.4',
#    'pression': '1018.8',
#    'humidite': '95',
#    'point_de_rosee': '5',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '134',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 01:30:00',
#    'temperature': '5.2',
#    'pression': '1018.7',
#    'humidite': '95',
#    'point_de_rosee': '4.4',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '134',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 01:40:00',
#    'temperature': '5',
#    'pression': '1018.7',
#    'humidite': '95',
#    'point_de_rosee': '4.4',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '134',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 01:50:00',
#    'temperature': '4.9',
#    'pression': '1018.7',
#    'humidite': '95',
#    'point_de_rosee': '4.4',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '134',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 02:00:00',
#    'temperature': '4.8',
#    'pression': '1018.6',
#    'humidite': '96',
#    'point_de_rosee': '4.4',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '134',
#    'pluie_3h': None,
#    'pluie_1h': '0'},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 02:10:00',
#    'temperature': '4.8',
#    'pression': '1018.6',
#    'humidite': '96',
#    'point_de_rosee': '4.4',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '134',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 02:20:00',
#    'temperature': '4.8',
#    'pression': '1018.5',
#    'humidite': '96',
#    'point_de_rosee': '4.4',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '134',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 02:30:00',
#    'temperature': '4.9',
#    'pression': '1018.5',
#    'humidite': '96',
#    'point_de_rosee': '4.4',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '134',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 02:40:00',
#    'temperature': '4.8',
#    'pression': '1018.5',
#    'humidite': '96',
#    'point_de_rosee': '4.4',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '134',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 02:50:00',
#    'temperature': '4.7',
#    'pression': '1018.5',
#    'humidite': '96',
#    'point_de_rosee': '3.9',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '134',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 03:00:00',
#    'temperature': '4.6',
#    'pression': '1018.5',
#    'humidite': '96',
#    'point_de_rosee': '3.9',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '134',
#    'pluie_3h': None,
#    'pluie_1h': '0'},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 03:10:00',
#    'temperature': '4.4',
#    'pression': '1018.4',
#    'humidite': '96',
#    'point_de_rosee': '3.9',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '134',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 03:20:00',
#    'temperature': '4.3',
#    'pression': '1018.4',
#    'humidite': '96',
#    'point_de_rosee': '3.9',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '134',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 03:30:00',
#    'temperature': '4.1',
#    'pression': '1018.3',
#    'humidite': '96',
#    'point_de_rosee': '3.3',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '134',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 03:40:00',
#    'temperature': '4.1',
#    'pression': '1018.3',
#    'humidite': '96',
#    'point_de_rosee': '3.3',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '134',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 03:50:00',
#    'temperature': '3.9',
#    'pression': '1018.3',
#    'humidite': '96',
#    'point_de_rosee': '3.3',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '134',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 04:00:00',
#    'temperature': '3.9',
#    'pression': '1018.2',
#    'humidite': '96',
#    'point_de_rosee': '3.3',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '134',
#    'pluie_3h': None,
#    'pluie_1h': '0'},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 04:10:00',
#    'temperature': '4.1',
#    'pression': '1018.2',
#    'humidite': '97',
#    'point_de_rosee': '3.9',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '134',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 04:20:00',
#    'temperature': '4.1',
#    'pression': '1018.1',
#    'humidite': '97',
#    'point_de_rosee': '3.9',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '134',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 04:30:00',
#    'temperature': '3.9',
#    'pression': '1018.2',
#    'humidite': '96',
#    'point_de_rosee': '3.3',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '134',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 04:40:00',
#    'temperature': '3.8',
#    'pression': '1018.2',
#    'humidite': '96',
#    'point_de_rosee': '3.3',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '134',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 04:50:00',
#    'temperature': '3.7',
#    'pression': '1018.1',
#    'humidite': '96',
#    'point_de_rosee': '3.3',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '134',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 05:00:00',
#    'temperature': '3.7',
#    'pression': '1018.1',
#    'humidite': '97',
#    'point_de_rosee': '3.3',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '134',
#    'pluie_3h': None,
#    'pluie_1h': '0'},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 05:10:00',
#    'temperature': '3.8',
#    'pression': '1018.1',
#    'humidite': '97',
#    'point_de_rosee': '3.3',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '134',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 05:20:00',
#    'temperature': '3.8',
#    'pression': '1018.1',
#    'humidite': '97',
#    'point_de_rosee': '3.3',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '134',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 05:30:00',
#    'temperature': '3.6',
#    'pression': '1018',
#    'humidite': '96',
#    'point_de_rosee': '3.3',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '134',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 05:40:00',
#    'temperature': '3.4',
#    'pression': '1017.9',
#    'humidite': '96',
#    'point_de_rosee': '2.8',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '134',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 05:50:00',
#    'temperature': '3.5',
#    'pression': '1017.8',
#    'humidite': '97',
#    'point_de_rosee': '3.3',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '134',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 06:00:00',
#    'temperature': '3.5',
#    'pression': '1017.9',
#    'humidite': '97',
#    'point_de_rosee': '3.3',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '134',
#    'pluie_3h': None,
#    'pluie_1h': '0'},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 06:10:00',
#    'temperature': '3.4',
#    'pression': '1017.8',
#    'humidite': '97',
#    'point_de_rosee': '3.3',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '134',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 06:20:00',
#    'temperature': '3.6',
#    'pression': '1017.8',
#    'humidite': '97',
#    'point_de_rosee': '3.3',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '134',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 06:30:00',
#    'temperature': '3.6',
#    'pression': '1017.8',
#    'humidite': '97',
#    'point_de_rosee': '3.3',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '134',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 06:40:00',
#    'temperature': '3.7',
#    'pression': '1017.8',
#    'humidite': '97',
#    'point_de_rosee': '3.3',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '134',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 06:50:00',
#    'temperature': '3.8',
#    'pression': '1017.7',
#    'humidite': '97',
#    'point_de_rosee': '3.3',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '134',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 07:00:00',
#    'temperature': '4.1',
#    'pression': '1017.8',
#    'humidite': '97',
#    'point_de_rosee': '3.9',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '134',
#    'pluie_3h': None,
#    'pluie_1h': '0'},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 07:10:00',
#    'temperature': '4.4',
#    'pression': '1017.7',
#    'humidite': '97',
#    'point_de_rosee': '3.9',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '134',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 07:20:00',
#    'temperature': '5.7',
#    'pression': '1017.8',
#    'humidite': '98',
#    'point_de_rosee': '5.6',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '134',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 07:30:00',
#    'temperature': '6.5',
#    'pression': '1017.9',
#    'humidite': '98',
#    'point_de_rosee': '6.1',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '234',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 07:40:00',
#    'temperature': '7.2',
#    'pression': '1017.8',
#    'humidite': '98',
#    'point_de_rosee': '6.7',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '234',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 07:50:00',
#    'temperature': '8.1',
#    'pression': '1017.8',
#    'humidite': '98',
#    'point_de_rosee': '7.8',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '234',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 08:00:00',
#    'temperature': '8.9',
#    'pression': '1017.8',
#    'humidite': '97',
#    'point_de_rosee': '8.3',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '234',
#    'pluie_3h': None,
#    'pluie_1h': '0'},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 08:10:00',
#    'temperature': '9.2',
#    'pression': '1017.7',
#    'humidite': '93',
#    'point_de_rosee': '8.3',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '227',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 08:20:00',
#    'temperature': '10.3',
#    'pression': '1017.9',
#    'humidite': '90',
#    'point_de_rosee': '8.9',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '227',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 08:30:00',
#    'temperature': '10.7',
#    'pression': '1017.8',
#    'humidite': '86',
#    'point_de_rosee': '8.3',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '225',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 08:40:00',
#    'temperature': '10.9',
#    'pression': '1017.9',
#    'humidite': '85',
#    'point_de_rosee': '8.3',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '223',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 08:50:00',
#    'temperature': '11.3',
#    'pression': '1017.8',
#    'humidite': '85',
#    'point_de_rosee': '8.9',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '224',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 09:00:00',
#    'temperature': '11.9',
#    'pression': '1017.9',
#    'humidite': '83',
#    'point_de_rosee': '8.9',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '226',
#    'pluie_3h': None,
#    'pluie_1h': '0'},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 09:10:00',
#    'temperature': '12.1',
#    'pression': '1017.8',
#    'humidite': '82',
#    'point_de_rosee': '8.9',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '223',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 09:20:00',
#    'temperature': '12.3',
#    'pression': '1017.8',
#    'humidite': '81',
#    'point_de_rosee': '9.4',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '239',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 09:30:00',
#    'temperature': '12.7',
#    'pression': '1017.6',
#    'humidite': '81',
#    'point_de_rosee': '9.4',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '246',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 09:40:00',
#    'temperature': '13',
#    'pression': '1017.5',
#    'humidite': '80',
#    'point_de_rosee': '9.4',
#    'vent_moyen': '1.6',
#    'vent_rafales': None,
#    'vent_direction': '240',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 09:50:00',
#    'temperature': '13.4',
#    'pression': '1017.4',
#    'humidite': '78',
#    'point_de_rosee': '9.4',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '232',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 10:00:00',
#    'temperature': '13.5',
#    'pression': '1017.3',
#    'humidite': '78',
#    'point_de_rosee': '10',
#    'vent_moyen': '1.6',
#    'vent_rafales': None,
#    'vent_direction': '232',
#    'pluie_3h': None,
#    'pluie_1h': '0'},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 10:10:00',
#    'temperature': '14',
#    'pression': '1017.2',
#    'humidite': '76',
#    'point_de_rosee': '10',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '234',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 10:20:00',
#    'temperature': '13.9',
#    'pression': '1017.1',
#    'humidite': '76',
#    'point_de_rosee': '10',
#    'vent_moyen': '1.6',
#    'vent_rafales': None,
#    'vent_direction': '234',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 10:30:00',
#    'temperature': '14.3',
#    'pression': '1017',
#    'humidite': '76',
#    'point_de_rosee': '10',
#    'vent_moyen': '1.6',
#    'vent_rafales': None,
#    'vent_direction': '245',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 10:40:00',
#    'temperature': '14.7',
#    'pression': '1016.9',
#    'humidite': '75',
#    'point_de_rosee': '10.6',
#    'vent_moyen': '1.6',
#    'vent_rafales': None,
#    'vent_direction': '65',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 10:50:00',
#    'temperature': '15.1',
#    'pression': '1016.8',
#    'humidite': '73',
#    'point_de_rosee': '10',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '274',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 11:00:00',
#    'temperature': '15.3',
#    'pression': '1016.6',
#    'humidite': '71',
#    'point_de_rosee': '10',
#    'vent_moyen': '1.6',
#    'vent_rafales': None,
#    'vent_direction': '57',
#    'pluie_3h': None,
#    'pluie_1h': '0'},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 11:10:00',
#    'temperature': '15.3',
#    'pression': '1016.5',
#    'humidite': '70',
#    'point_de_rosee': '10',
#    'vent_moyen': '1.6',
#    'vent_rafales': None,
#    'vent_direction': '258',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 11:20:00',
#    'temperature': '15.7',
#    'pression': '1016.3',
#    'humidite': '70',
#    'point_de_rosee': '10',
#    'vent_moyen': '1.6',
#    'vent_rafales': None,
#    'vent_direction': '258',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 11:30:00',
#    'temperature': '16.1',
#    'pression': '1016.1',
#    'humidite': '68',
#    'point_de_rosee': '10',
#    'vent_moyen': '1.6',
#    'vent_rafales': None,
#    'vent_direction': '259',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 11:40:00',
#    'temperature': '16.2',
#    'pression': '1015.9',
#    'humidite': '65',
#    'point_de_rosee': '9.4',
#    'vent_moyen': '3.2',
#    'vent_rafales': None,
#    'vent_direction': '48',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 11:50:00',
#    'temperature': '16.5',
#    'pression': '1015.8',
#    'humidite': '65',
#    'point_de_rosee': '10',
#    'vent_moyen': '1.6',
#    'vent_rafales': None,
#    'vent_direction': '118',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 12:00:00',
#    'temperature': '16.5',
#    'pression': '1015.6',
#    'humidite': '62',
#    'point_de_rosee': '8.9',
#    'vent_moyen': '1.6',
#    'vent_rafales': None,
#    'vent_direction': '269',
#    'pluie_3h': None,
#    'pluie_1h': '0'},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 12:10:00',
#    'temperature': '16.7',
#    'pression': '1015.4',
#    'humidite': '62',
#    'point_de_rosee': '9.4',
#    'vent_moyen': '1.6',
#    'vent_rafales': None,
#    'vent_direction': '225',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 12:20:00',
#    'temperature': '16.7',
#    'pression': '1015.3',
#    'humidite': '61',
#    'point_de_rosee': '8.9',
#    'vent_moyen': '3.2',
#    'vent_rafales': None,
#    'vent_direction': '257',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 12:30:00',
#    'temperature': '16.7',
#    'pression': '1015.1',
#    'humidite': '61',
#    'point_de_rosee': '8.9',
#    'vent_moyen': '1.6',
#    'vent_rafales': None,
#    'vent_direction': '274',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 12:40:00',
#    'temperature': '16.8',
#    'pression': '1014.9',
#    'humidite': '61',
#    'point_de_rosee': '8.9',
#    'vent_moyen': '1.6',
#    'vent_rafales': None,
#    'vent_direction': '247',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 12:50:00',
#    'temperature': '16.9',
#    'pression': '1014.8',
#    'humidite': '60',
#    'point_de_rosee': '8.9',
#    'vent_moyen': '3.2',
#    'vent_rafales': None,
#    'vent_direction': '45',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 13:00:00',
#    'temperature': '17',
#    'pression': '1014.6',
#    'humidite': '60',
#    'point_de_rosee': '8.9',
#    'vent_moyen': '3.2',
#    'vent_rafales': None,
#    'vent_direction': '313',
#    'pluie_3h': None,
#    'pluie_1h': '0'},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 13:10:00',
#    'temperature': '16.8',
#    'pression': '1014.5',
#    'humidite': '60',
#    'point_de_rosee': '8.9',
#    'vent_moyen': '1.6',
#    'vent_rafales': None,
#    'vent_direction': '271',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 13:20:00',
#    'temperature': '16.8',
#    'pression': '1014.4',
#    'humidite': '59',
#    'point_de_rosee': '8.3',
#    'vent_moyen': '1.6',
#    'vent_rafales': None,
#    'vent_direction': '270',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 13:30:00',
#    'temperature': '17.2',
#    'pression': '1014.5',
#    'humidite': '60',
#    'point_de_rosee': '9.4',
#    'vent_moyen': '1.6',
#    'vent_rafales': None,
#    'vent_direction': '215',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
#    'dh_utc': '2024-10-05 13:40:00',
#    'temperature': '17.1',
#    'pression': '1014.4',
#    'humidite': '59',
#    'point_de_rosee': '8.9',
#    'vent_moyen': '1.6',
#    'vent_rafales': None,
#    'vent_direction': '54',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': '00052',
# ...
#    'vent_direction': '148',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': 'STATIC0010',
#    'dh_utc': '2024-10-07 03:00:00',
#    'temperature': '13.4',
#    'pression': '1000.6',
#    'humidite': '96',
#    'point_de_rosee': '12.8',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '168',
#    'pluie_3h': None,
#    'pluie_1h': '0'},
#   {'id_station': 'STATIC0010',
#    'dh_utc': '2024-10-07 03:10:00',
#    'temperature': '13.3',
#    'pression': '1000.6',
#    'humidite': '97',
#    'point_de_rosee': '12.7',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '0',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': 'STATIC0010',
#    'dh_utc': '2024-10-07 03:20:00',
#    'temperature': '13.3',
#    'pression': '1000.7',
#    'humidite': '97',
#    'point_de_rosee': '12.8',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '0',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': 'STATIC0010',
#    'dh_utc': '2024-10-07 03:30:00',
#    'temperature': '13.2',
#    'pression': '1000.7',
#    'humidite': '97',
#    'point_de_rosee': '12.7',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '0',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': 'STATIC0010',
#    'dh_utc': '2024-10-07 03:40:00',
#    'temperature': '13.1',
#    'pression': '1000.8',
#    'humidite': '97',
#    'point_de_rosee': '12.6',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '0',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': 'STATIC0010',
#    'dh_utc': '2024-10-07 03:50:00',
#    'temperature': '13',
#    'pression': '1000.8',
#    'humidite': '97',
#    'point_de_rosee': '12.6',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '164',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': 'STATIC0010',
#    'dh_utc': '2024-10-07 04:00:00',
#    'temperature': '12.9',
#    'pression': '1001.1',
#    'humidite': '97',
#    'point_de_rosee': '12.4',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '156',
#    'pluie_3h': None,
#    'pluie_1h': '0'},
#   {'id_station': 'STATIC0010',
#    'dh_utc': '2024-10-07 04:10:00',
#    'temperature': '12.8',
#    'pression': '1001.2',
#    'humidite': '97',
#    'point_de_rosee': '12.3',
#    'vent_moyen': '0.3',
#    'vent_rafales': None,
#    'vent_direction': '167',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': 'STATIC0010',
#    'dh_utc': '2024-10-07 04:20:00',
#    'temperature': '12.7',
#    'pression': '1001.2',
#    'humidite': '97',
#    'point_de_rosee': '12.3',
#    'vent_moyen': '1',
#    'vent_rafales': None,
#    'vent_direction': '184',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': 'STATIC0010',
#    'dh_utc': '2024-10-07 04:30:00',
#    'temperature': '12.6',
#    'pression': '1001',
#    'humidite': '97',
#    'point_de_rosee': '12.2',
#    'vent_moyen': '0.2',
#    'vent_rafales': None,
#    'vent_direction': '215',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': 'STATIC0010',
#    'dh_utc': '2024-10-07 04:40:00',
#    'temperature': '12.5',
#    'pression': '1001.1',
#    'humidite': '97',
#    'point_de_rosee': '12.1',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '167',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': 'STATIC0010',
#    'dh_utc': '2024-10-07 04:50:00',
#    'temperature': '12.4',
#    'pression': '1001.2',
#    'humidite': '97',
#    'point_de_rosee': '12',
#    'vent_moyen': '0.3',
#    'vent_rafales': None,
#    'vent_direction': '171',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': 'STATIC0010',
#    'dh_utc': '2024-10-07 05:00:00',
#    'temperature': '12.3',
#    'pression': '1001.3',
#    'humidite': '97',
#    'point_de_rosee': '11.9',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '235',
#    'pluie_3h': None,
#    'pluie_1h': '0'},
#   {'id_station': 'STATIC0010',
#    'dh_utc': '2024-10-07 05:10:00',
#    'temperature': '12.3',
#    'pression': '1001.3',
#    'humidite': '97',
#    'point_de_rosee': '11.8',
#    'vent_moyen': '0.1',
#    'vent_rafales': None,
#    'vent_direction': '235',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': 'STATIC0010',
#    'dh_utc': '2024-10-07 05:20:00',
#    'temperature': '12.2',
#    'pression': '1001.3',
#    'humidite': '97',
#    'point_de_rosee': '11.7',
#    'vent_moyen': '0.4',
#    'vent_rafales': None,
#    'vent_direction': '232',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': 'STATIC0010',
#    'dh_utc': '2024-10-07 05:30:00',
#    'temperature': '12.1',
#    'pression': '1001.4',
#    'humidite': '97',
#    'point_de_rosee': '11.7',
#    'vent_moyen': '0.1',
#    'vent_rafales': None,
#    'vent_direction': '192',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': 'STATIC0010',
#    'dh_utc': '2024-10-07 05:40:00',
#    'temperature': '12.2',
#    'pression': '1001.4',
#    'humidite': '98',
#    'point_de_rosee': '11.8',
#    'vent_moyen': '0.5',
#    'vent_rafales': None,
#    'vent_direction': '188',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': 'STATIC0010',
#    'dh_utc': '2024-10-07 05:50:00',
#    'temperature': '12.2',
#    'pression': '1001.5',
#    'humidite': '97',
#    'point_de_rosee': '11.8',
#    'vent_moyen': '0.2',
#    'vent_rafales': None,
#    'vent_direction': '186',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': 'STATIC0010',
#    'dh_utc': '2024-10-07 06:00:00',
#    'temperature': '12.1',
#    'pression': '1001.5',
#    'humidite': '97',
#    'point_de_rosee': '11.7',
#    'vent_moyen': '0.2',
#    'vent_rafales': None,
#    'vent_direction': '203',
#    'pluie_3h': None,
#    'pluie_1h': '0'},
#   {'id_station': 'STATIC0010',
#    'dh_utc': '2024-10-07 06:10:00',
#    'temperature': '12.1',
#    'pression': '1001.5',
#    'humidite': '97',
#    'point_de_rosee': '11.6',
#    'vent_moyen': '0.1',
#    'vent_rafales': None,
#    'vent_direction': '161',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': 'STATIC0010',
#    'dh_utc': '2024-10-07 06:20:00',
#    'temperature': '11.9',
#    'pression': '1001.5',
#    'humidite': '97',
#    'point_de_rosee': '11.4',
#    'vent_moyen': '0.1',
#    'vent_rafales': None,
#    'vent_direction': '164',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': 'STATIC0010',
#    'dh_utc': '2024-10-07 06:30:00',
#    'temperature': '11.8',
#    'pression': '1001.6',
#    'humidite': '97',
#    'point_de_rosee': '11.3',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '0',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': 'STATIC0010',
#    'dh_utc': '2024-10-07 06:40:00',
#    'temperature': '11.7',
#    'pression': '1001.5',
#    'humidite': '97',
#    'point_de_rosee': '11.2',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '0',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': 'STATIC0010',
#    'dh_utc': '2024-10-07 06:50:00',
#    'temperature': '11.9',
#    'pression': '1001.6',
#    'humidite': '98',
#    'point_de_rosee': '11.5',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '0',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': 'STATIC0010',
#    'dh_utc': '2024-10-07 07:00:00',
#    'temperature': '12.2',
#    'pression': '1001.6',
#    'humidite': '98',
#    'point_de_rosee': '11.8',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '165',
#    'pluie_3h': None,
#    'pluie_1h': '0'},
#   {'id_station': 'STATIC0010',
#    'dh_utc': '2024-10-07 07:10:00',
#    'temperature': '12.4',
#    'pression': '1001.6',
#    'humidite': '98',
#    'point_de_rosee': '12.1',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': None,
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': 'STATIC0010',
#    'dh_utc': '2024-10-07 07:20:00',
#    'temperature': '12.7',
#    'pression': '1001.7',
#    'humidite': '97',
#    'point_de_rosee': '12.2',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '0',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': 'STATIC0010',
#    'dh_utc': '2024-10-07 07:30:00',
#    'temperature': '12.8',
#    'pression': '1001.8',
#    'humidite': '97',
#    'point_de_rosee': '12.4',
#    'vent_moyen': '0',
#    'vent_rafales': None,
#    'vent_direction': '155',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': 'STATIC0010',
#    'dh_utc': '2024-10-07 07:40:00',
#    'temperature': '13',
#    'pression': '1001.9',
#    'humidite': '97',
#    'point_de_rosee': '12.4',
#    'vent_moyen': '0.3',
#    'vent_rafales': None,
#    'vent_direction': '206',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': 'STATIC0010',
#    'dh_utc': '2024-10-07 07:50:00',
#    'temperature': '13.1',
#    'pression': '1001.9',
#    'humidite': '96',
#    'point_de_rosee': '12.5',
#    'vent_moyen': '0.6',
#    'vent_rafales': None,
#    'vent_direction': '214',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': 'STATIC0010',
#    'dh_utc': '2024-10-07 08:00:00',
#    'temperature': '13.3',
#    'pression': '1002.3',
#    'humidite': '96',
#    'point_de_rosee': '12.8',
#    'vent_moyen': '0.6',
#    'vent_rafales': None,
#    'vent_direction': '220',
#    'pluie_3h': None,
#    'pluie_1h': '0'},
#   {'id_station': 'STATIC0010',
#    'dh_utc': '2024-10-07 08:10:00',
#    'temperature': '13.7',
#    'pression': '1002.3',
#    'humidite': '96',
#    'point_de_rosee': '13',
#    'vent_moyen': '0.8',
#    'vent_rafales': None,
#    'vent_direction': '208',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': 'STATIC0010',
#    'dh_utc': '2024-10-07 08:20:00',
#    'temperature': '13.8',
#    'pression': '1002.6',
#    'humidite': '95',
#    'point_de_rosee': '13.1',
#    'vent_moyen': '1.7',
#    'vent_rafales': None,
#    'vent_direction': '205',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': 'STATIC0010',
#    'dh_utc': '2024-10-07 08:30:00',
#    'temperature': '14.1',
#    'pression': '1002.7',
#    'humidite': '95',
#    'point_de_rosee': '13.3',
#    'vent_moyen': '1.5',
#    'vent_rafales': None,
#    'vent_direction': '201',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': 'STATIC0010',
#    'dh_utc': '2024-10-07 08:40:00',
#    'temperature': '14.4',
#    'pression': '1002.8',
#    'humidite': '94',
#    'point_de_rosee': '13.6',
#    'vent_moyen': '1',
#    'vent_rafales': None,
#    'vent_direction': '212',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': 'STATIC0010',
#    'dh_utc': '2024-10-07 08:50:00',
#    'temperature': '14.8',
#    'pression': '1002.9',
#    'humidite': '93',
#    'point_de_rosee': '13.7',
#    'vent_moyen': '1.9',
#    'vent_rafales': None,
#    'vent_direction': '230',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': 'STATIC0010',
#    'dh_utc': '2024-10-07 09:00:00',
#    'temperature': '15.1',
#    'pression': '1002.9',
#    'humidite': '92',
#    'point_de_rosee': '13.8',
#    'vent_moyen': '2.4',
#    'vent_rafales': None,
#    'vent_direction': '242',
#    'pluie_3h': None,
#    'pluie_1h': '0'},
#   {'id_station': 'STATIC0010',
#    'dh_utc': '2024-10-07 09:10:00',
#    'temperature': '14.8',
#    'pression': '1002.5',
#    'humidite': '91',
#    'point_de_rosee': '13.3',
#    'vent_moyen': '3.2',
#    'vent_rafales': None,
#    'vent_direction': '249',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': 'STATIC0010',
#    'dh_utc': '2024-10-07 09:20:00',
#    'temperature': '14.9',
#    'pression': '1002.6',
#    'humidite': '92',
#    'point_de_rosee': '13.7',
#    'vent_moyen': '1',
#    'vent_rafales': None,
#    'vent_direction': None,
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': 'STATIC0010',
#    'dh_utc': '2024-10-07 09:30:00',
#    'temperature': '15.1',
#    'pression': '1002.5',
#    'humidite': '91',
#    'point_de_rosee': '13.6',
#    'vent_moyen': '0.6',
#    'vent_rafales': None,
#    'vent_direction': '214',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': 'STATIC0010',
#    'dh_utc': '2024-10-07 09:40:00',
#    'temperature': '15.3',
#    'pression': '1002.6',
#    'humidite': '92',
#    'point_de_rosee': '13.9',
#    'vent_moyen': '0.2',
#    'vent_rafales': None,
#    'vent_direction': '263',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': 'STATIC0010',
#    'dh_utc': '2024-10-07 09:50:00',
#    'temperature': '15.6',
#    'pression': '1002.7',
#    'humidite': '91',
#    'point_de_rosee': '14.1',
#    'vent_moyen': '0.4',
#    'vent_rafales': None,
#    'vent_direction': '228',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': 'STATIC0010',
#    'dh_utc': '2024-10-07 10:00:00',
#    'temperature': '16',
#    'pression': '1002.5',
#    'humidite': '89',
#    'point_de_rosee': '14.2',
#    'vent_moyen': '1.3',
#    'vent_rafales': None,
#    'vent_direction': '198',
#    'pluie_3h': None,
#    'pluie_1h': '0'},
#   {'id_station': 'STATIC0010',
#    'dh_utc': '2024-10-07 10:10:00',
#    'temperature': '16.3',
#    'pression': '1002.5',
#    'humidite': '87',
#    'point_de_rosee': '14.2',
#    'vent_moyen': '0.6',
#    'vent_rafales': None,
#    'vent_direction': '204',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': 'STATIC0010',
#    'dh_utc': '2024-10-07 10:20:00',
#    'temperature': '16.3',
#    'pression': '1002.6',
#    'humidite': '87',
#    'point_de_rosee': '14.1',
#    'vent_moyen': '1.3',
#    'vent_rafales': None,
#    'vent_direction': '191',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': 'STATIC0010',
#    'dh_utc': '2024-10-07 10:30:00',
#    'temperature': '16.5',
#    'pression': '1002.8',
#    'humidite': '88',
#    'point_de_rosee': '14.4',
#    'vent_moyen': '0.4',
#    'vent_rafales': None,
#    'vent_direction': '165',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': 'STATIC0010',
#    'dh_utc': '2024-10-07 10:40:00',
#    'temperature': '16.8',
#    'pression': '1002.7',
#    'humidite': '86',
#    'point_de_rosee': '14.4',
#    'vent_moyen': '1.1',
#    'vent_rafales': None,
#    'vent_direction': '188',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': 'STATIC0010',
#    'dh_utc': '2024-10-07 10:50:00',
#    'temperature': '17.1',
#    'pression': '1002.7',
#    'humidite': '85',
#    'point_de_rosee': '14.5',
#    'vent_moyen': '1.1',
#    'vent_rafales': None,
#    'vent_direction': '197',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': 'STATIC0010',
#    'dh_utc': '2024-10-07 11:00:00',
#    'temperature': '17.3',
#    'pression': '1002.7',
#    'humidite': '83',
#    'point_de_rosee': '14.5',
#    'vent_moyen': '1.6',
#    'vent_rafales': None,
#    'vent_direction': '183',
#    'pluie_3h': None,
#    'pluie_1h': '0'},
#   {'id_station': 'STATIC0010',
#    'dh_utc': '2024-10-07 11:10:00',
#    'temperature': '17.8',
#    'pression': '1002.6',
#    'humidite': '82',
#    'point_de_rosee': '14.7',
#    'vent_moyen': '1',
#    'vent_rafales': None,
#    'vent_direction': '196',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': 'STATIC0010',
#    'dh_utc': '2024-10-07 11:20:00',
#    'temperature': '18.1',
#    'pression': '1002.5',
#    'humidite': '79',
#    'point_de_rosee': '14.4',
#    'vent_moyen': '1.6',
#    'vent_rafales': None,
#    'vent_direction': '179',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': 'STATIC0010',
#    'dh_utc': '2024-10-07 11:30:00',
#    'temperature': '18.1',
#    'pression': '1002.5',
#    'humidite': '77',
#    'point_de_rosee': '14',
#    'vent_moyen': '1',
#    'vent_rafales': None,
#    'vent_direction': '191',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': 'STATIC0010',
#    'dh_utc': '2024-10-07 11:40:00',
#    'temperature': '18.1',
#    'pression': '1002.5',
#    'humidite': '79',
#    'point_de_rosee': '14.3',
#    'vent_moyen': '1.2',
#    'vent_rafales': None,
#    'vent_direction': '223',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': 'STATIC0010',
#    'dh_utc': '2024-10-07 11:50:00',
#    'temperature': '18.2',
#    'pression': '1002.4',
#    'humidite': '77',
#    'point_de_rosee': '14.1',
#    'vent_moyen': '1.1',
#    'vent_rafales': None,
#    'vent_direction': '181',
#    'pluie_3h': None,
#    'pluie_1h': None},
#   {'id_station': 'STATIC0010',
#    'dh_utc': '2024-10-07 12:00:00',
#    'temperature': '18.2',
#    'pression': '1002.3',
#    'humidite': '76',
#    'point_de_rosee': '14',
#    'vent_moyen': '0.8',
#    'vent_rafales': None,
#    'vent_direction': '183',
#    'pluie_3h': None,
#    'pluie_1h': '0'}],
#  'hourly._params': ['temperature',
#   'pression',
#   'humidite',
#   'point_de_rosee',
#   'vent_moyen',
#   'vent_rafales',
#   'vent_direction',
#   'pluie_3h',
#   'pluie_1h']}

# %%
data_to_insert[0]["stations"]
# Out:
# [{'id': '00052',
#   'name': 'Armentières',
#   'latitude': 50.689,
#   'longitude': 2.877,
#   'elevation': 16,
#   'type': 'static',
#   'license': {'license': 'CC BY',
#    'url': 'https://creativecommons.org/licenses/by/2.0/fr/',
#    'source': 'infoclimat.fr',
#    'metadonnees': 'https://www.infoclimat.fr/stations/metadonnees.php?id=00052'}},
#  {'id': '000R5',
#   'name': 'Bergues',
#   'latitude': 50.968,
#   'longitude': 2.441,
#   'elevation': 17,
#   'type': 'static',
#   'license': {'license': 'CC BY',
#    'url': 'https://creativecommons.org/licenses/by/2.0/fr/',
#    'source': 'infoclimat.fr',
#    'metadonnees': 'https://www.infoclimat.fr/stations/metadonnees.php?id=000R5'}},
#  {'id': '07015',
#   'name': 'Lille-Lesquin',
#   'latitude': 50.575,
#   'longitude': 3.092,
#   'elevation': 47,
#   'type': 'synop',
#   'license': {'license': 'Etalab Open License',
#    'url': 'https://www.etalab.gouv.fr/licence-ouverte-open-licence',
#    'source': 'Meteo-France via infoclimat.fr',
#    'metadonnees': 'https://donneespubliques.meteofrance.fr/metadonnees_publiques/fiches/fiche_59343001.pdf'}},
#  {'id': 'STATIC0010',
#   'name': 'Hazebrouck',
#   'latitude': 50.734,
#   'longitude': 2.545,
#   'elevation': 31,
#   'type': 'static',
#   'license': {'license': 'CC BY',
#    'url': 'https://creativecommons.org/licenses/by/2.0/fr/',
#    'source': 'infoclimat.fr',
#    'metadonnees': 'https://www.infoclimat.fr/stations/metadonnees.php?id=STATIC0010'}}]

# %%
data_to_insert[0]['hourly.STATIC0010'][0:3]
# Out:
# [{'id_station': 'STATIC0010',
#   'dh_utc': '2024-10-05 00:00:00',
#   'temperature': '4.7',
#   'pression': '1020.6',
#   'humidite': '97',
#   'point_de_rosee': '4.2',
#   'vent_moyen': '0',
#   'vent_rafales': None,
#   'vent_direction': '0',
#   'pluie_3h': None,
#   'pluie_1h': '0'},
#  {'id_station': 'STATIC0010',
#   'dh_utc': '2024-10-05 00:10:00',
#   'temperature': '4.7',
#   'pression': '1020.7',
#   'humidite': '97',
#   'point_de_rosee': '4.2',
#   'vent_moyen': '0',
#   'vent_rafales': None,
#   'vent_direction': '0',
#   'pluie_3h': None,
#   'pluie_1h': None},
#  {'id_station': 'STATIC0010',
#   'dh_utc': '2024-10-05 00:20:00',
#   'temperature': '4.6',
#   'pression': '1020.6',
#   'humidite': '97',
#   'point_de_rosee': '4.1',
#   'vent_moyen': '0',
#   'vent_rafales': None,
#   'vent_direction': '0',
#   'pluie_3h': None,
#   'pluie_1h': None}]

# %%
data_to_insert[0]['hourly.07015'][3]
# Out:
# {'id_station': '07015',
#  'dh_utc': '2024-10-05 03:00:00',
#  'temperature': '6.2',
#  'pression': '1020.1',
#  'humidite': '95',
#  'point_de_rosee': '5.5',
#  'visibilite': '2500',
#  'vent_moyen': '3.6',
#  'vent_rafales': '7.2',
#  'vent_direction': '60',
#  'pluie_3h': '0',
#  'pluie_1h': '0',
#  'neige_au_sol': None,
#  'nebulosite': '',
#  'temps_omm': '10'}

# %%
for i in data_to_insert[0]['hourly.07015'][3].keys():
    j = data_to_insert[0]['hourly.07015'][3][i]
    print(type(j),"est le type de",j)
# Out:
# <class 'str'> est le type de 07015
# <class 'str'> est le type de 2024-10-05 03:00:00
# <class 'str'> est le type de 6.2
# <class 'str'> est le type de 1020.1
# <class 'str'> est le type de 95
# <class 'str'> est le type de 5.5
# <class 'str'> est le type de 2500
# <class 'str'> est le type de 3.6
# <class 'str'> est le type de 7.2
# <class 'str'> est le type de 60
# <class 'str'> est le type de 0
# <class 'str'> est le type de 0
# <class 'NoneType'> est le type de None
# <class 'str'> est le type de
# <class 'str'> est le type de 10

# %%
# ✅ 1. Connect to MongoDB
client = MongoClient(mongodb_address)  # Update if needed
db = client["weather_data"]  # Your database name
collection = db["weather_station"]  # Collection name


# ✅ 2. Load the JSON data (assuming it's in a file or a variable)
weather_data = data_to_insert

# ✅ 3. Extract Relevant Data
stations = weather_data[0].get("stations", [])  # Extract station metadata
hourly_data = {
    key: weather_data[0][key]
    for key in weather_data[0]
    if key.startswith("hourly.") and key != "hourly._params"
}

# ✅ 4. Flatten Hourly Data
flattened_data = []
for station_id, records in hourly_data.items():
    for record in records:
        flattened_data.append(record)  # Convert list of dicts into single list

# %%
Id_to_station = {station['id']: station['name'] for station in data_to_insert[0]["stations"]}
Id_to_station
# Out:
# {'00052': 'Armentières',
#  '000R5': 'Bergues',
#  '07015': 'Lille-Lesquin',
#  'STATIC0010': 'Hazebrouck'}

# %%
for doc in flattened_data:
    doc['station'] = Id_to_station.get(doc['id_station'], 'Unknown')

# %%
from datetime import datetime
import copy

def process_data(document):
    document = copy.deepcopy(document)
    # Convert strings to appropriate types
    document['dh_utc'] = datetime.strptime(document['dh_utc'], '%Y-%m-%d %H:%M:%S')  # Convert to datetime, must start as str
    # Ensure all fields are converted properly, handling missing keys
    document['temperature'] = float(document['temperature']) if document.get('temperature') else None
    document['pression'] = float(document['pression']) if document.get('pression') else None
    document['humidite'] = int(document['humidite']) if document.get('humidite') else None
    document['point_de_rosee'] = float(document['point_de_rosee']) if document.get('point_de_rosee') else None
    document['visibilite'] = int(document.get('visibilite', 0)) if document.get('visibilite') else None
    document['vent_moyen'] = float(document['vent_moyen']) if document.get('vent_moyen') else None
    document['vent_rafales'] = float(document['vent_rafales']) if document.get('vent_rafales') else None
    document['vent_direction'] = int(document['vent_direction']) if document.get('vent_direction') else None
    document['pluie_3h'] = float(document['pluie_3h']) if document.get('pluie_3h') else None
    document['pluie_1h'] = float(document['pluie_1h']) if document.get('pluie_1h') else None
    document['neige_au_sol'] = float(document.get('neige_au_sol', 0)) if document.get('neige_au_sol') else None
    document['nebulosite'] = str(document.get('nebulosite', '')) if document.get('nebulosite') else ''
    document['temps_omm'] = float(document.get('temps_omm', 0)) if document.get('temps_omm') else None
    

    return document

# %%
def process_data2(document):
    # Define a mapping of fields to their conversion functions
    conversion_map = {
        'dh_utc': lambda x: datetime.strptime(x, '%Y-%m-%d %H:%M:%S') if x else None,
        'temperature': lambda x: float(x) if x else None,
        'pression': lambda x: float(x) if x else None,
        'humidite': lambda x: int(x) if x else None,
        'point_de_rosee': lambda x: float(x) if x else None,
        'visibilite': lambda x: int(x) if x else None,
        'vent_moyen': lambda x: float(x) if x else None,
        'vent_rafales': lambda x: float(x) if x else None,
        'vent_direction': lambda x: int(x) if x else None,
        'pluie_3h': lambda x: float(x) if x else None,
        'pluie_1h': lambda x: float(x) if x else None,
        'neige_au_sol': lambda x: float(x) if x else None,
        'nebulosite': lambda x: str(x) if x else '',
        'temps_omm': lambda x: float(x) if x else None
    }

    # Use deepcopy to avoid mutating the original document
    document = copy.deepcopy(document)

    # Loop over the conversion map and apply the transformation if the field exists in the document
    for field, conversion_func in conversion_map.items():
        if field in document:
            document[field] = conversion_func(document[field])

    return document

# %%
def rename_columns(document):
    # Column renaming and translation mapping
    column_mapping = {
        'dh_utc': 'datetime',
        'temperature': 'temperature_°C',  # In Celsius
        'pression': 'pressure_hPa',  # In hPa
        'humidite': 'humidity_%',
        'point_de_rosee': 'dew_point_°C',  # In Celsius
        'visibilite': 'visibility_m',  # Assuming meters for visibility
        'vent_moyen': 'wind_speed_kph',  # In km/h
        'vent_rafales': 'wind_gust_kph',  # In km/h
        'vent_direction': 'wind_dir',  # Wind direction (unchanged)
        'pluie_3h': 'precip_rate_mm/hr (3hrs)',  # In mm/hr
        'pluie_1h': 'precip_rate_mm/hr',  # In mm/hr
        'neige_au_sol': 'snow_depth_mm',  # In mm
        'nebulosite': 'cloud_coverage',  # General cloud coverage (string or percentage)
        'temps_omm': 'solar_w/m²'  # Assuming temperature is related to solar irradiance
    }

    # Rename keys based on the mapping
    for old_key, new_key in column_mapping.items():
        if old_key in document:
            document[new_key] = document.pop(old_key)

    return document

# %%
document1 = process_data(flattened_data[4])
document1
# Out:
# {'id_station': '07015',
#  'dh_utc': datetime.datetime(2024, 10, 5, 4, 0),
#  'temperature': 5.5,
#  'pression': 1019.9,
#  'humidite': 96,
#  'point_de_rosee': 4.9,
#  'visibilite': 500,
#  'vent_moyen': 3.6,
#  'vent_rafales': 3.6,
#  'vent_direction': 90,
#  'pluie_3h': None,
#  'pluie_1h': 0.0,
#  'neige_au_sol': None,
#  'nebulosite': '',
#  'temps_omm': 44.0,
#  'station': 'Lille-Lesquin'}

# %%
rename_columns(document1)
# Out:
# {'id_station': '07015',
#  'station': 'Lille-Lesquin',
#  'datetime': datetime.datetime(2024, 10, 5, 4, 0),
#  'temperature_°C': 5.5,
#  'pressure_hPa': 1019.9,
#  'humidity_%': 96,
#  'dew_point_°C': 4.9,
#  'visibility_m': 500,
#  'wind_speed_kph': 3.6,
#  'wind_gust_kph': 3.6,
#  'wind_dir': 90,
#  'precip_rate_mm/hr (3hrs)': None,
#  'precip_rate_mm/hr': 0.0,
#  'snow_depth_mm': None,
#  'cloud_coverage': '',
#  'solar_w/m²': 44.0}

# %%
document1.keys()
# Out:
# dict_keys(['id_station', 'station', 'datetime', 'temperature_°C', 'pressure_hPa', 'humidity_%', 'dew_point_°C', 'visibility_m', 'wind_speed_kph', 'wind_gust_kph', 'wind_dir', 'precip_rate_mm/hr (3hrs)', 'precip_rate_mm/hr', 'snow_depth_mm', 'cloud_coverage', 'solar_w/m²'])

# %%
for i in document1.keys():
    j = document1[i]
    print(type(j),"est le type de",j)
# Out:
# <class 'str'> est le type de 07015
# <class 'str'> est le type de Lille-Lesquin
# <class 'datetime.datetime'> est le type de 2024-10-05 04:00:00
# <class 'float'> est le type de 5.5
# <class 'float'> est le type de 1019.9
# <class 'int'> est le type de 96
# <class 'float'> est le type de 4.9
# <class 'int'> est le type de 500
# <class 'float'> est le type de 3.6
# <class 'float'> est le type de 3.6
# <class 'int'> est le type de 90
# <class 'NoneType'> est le type de None
# <class 'float'> est le type de 0.0
# <class 'NoneType'> est le type de None
# <class 'str'> est le type de
# <class 'float'> est le type de 44.0

# %%
document1['datetime']
# Out:
# datetime.datetime(2024, 10, 5, 4, 0)

# %%
# ✅ 5.1. Convert into correct types
for i in flattened_data:
    i = process_data(i)

processed_data = [process_data(doc) for doc in flattened_data]

# ✅ 5.1.5 Convert the column names into the general ones
processed_data = [rename_columns(doc) for doc in processed_data]

# %%
processed_data[1:3]
# Out:
# [{'id_station': '07015',
#   'station': 'Lille-Lesquin',
#   'datetime': datetime.datetime(2024, 10, 5, 1, 0),
#   'temperature_°C': 7.5,
#   'pressure_hPa': 1020.6,
#   'humidity_%': 92,
#   'dew_point_°C': 6.3,
#   'visibility_m': 7000,
#   'wind_speed_kph': 3.6,
#   'wind_gust_kph': 7.2,
#   'wind_dir': 30,
#   'precip_rate_mm/hr (3hrs)': None,
#   'precip_rate_mm/hr': 0.0,
#   'snow_depth_mm': None,
#   'cloud_coverage': '',
#   'solar_w/m²': None},
#  {'id_station': '07015',
#   'station': 'Lille-Lesquin',
#   'datetime': datetime.datetime(2024, 10, 5, 2, 0),
#   'temperature_°C': 7.4,
#   'pressure_hPa': 1020.3,
#   'humidity_%': 93,
#   'dew_point_°C': 6.3,
#   'visibility_m': 4400,
#   'wind_speed_kph': 7.2,
#   'wind_gust_kph': 7.2,
#   'wind_dir': 40,
#   'precip_rate_mm/hr (3hrs)': None,
#   'precip_rate_mm/hr': 0.0,
#   'snow_depth_mm': None,
#   'cloud_coverage': '',
#   'solar_w/m²': 10.0}]

# %%
common_keys = set(processed_data[0].keys())
for doc in processed_data[1:]:
    common_keys &= set(doc.keys())
len(common_keys)
# Out:
# 16

# %%
# Set to hold unique keys
all_keys = set()

# Iterate over all documents in processed_data
for document in processed_data:
    all_keys.update(document.keys())
len(all_keys)
# Out:
# 16

# %%
# Function to generate ObjectId from a unique key
def generate_objectid(unique_str):
    hash_hex = hashlib.md5(unique_str.encode()).hexdigest()[:24]  # Ensure 24 chars
    return ObjectId(hash_hex)

# Add the ObjectId to each document in the list
for doc in processed_data:
    unique_str = str(doc['datetime']) + doc['station']
    doc['_id'] = generate_objectid(unique_str)

# %%
migration_tag = f"{datetime.now().strftime('%Y-%m-%d_%Hh%M')}_{args.file}"

for doc in processed_data:  # assuming data is a list of dicts
    doc["migrated"] = migration_tag

# %%
# Choose keys to track
numeric_keys = ["temperature_°C", "humidity_%", "pressure_hPa"]

# Filter and flatten values
metrics = {
    "migration_tag": migration_tag,
    "mongodb_address": mongodb_address,
    "row_count": len(processed_data),
}

for key in numeric_keys:
    values = [doc[key] for doc in processed_data if key in doc and isinstance(doc[key], (int, float)) and doc[key] is not None]
    if values:
        metrics[f"median_{key}"] = float(statistics.median(values))
        metrics[f"min_{key}"] = float(min(values))
        metrics[f"max_{key}"] = float(max(values))


try:
    script_dir = os.path.dirname(os.path.abspath(__file__))
except NameError:
    # In Jupyter, manually set the path or use os.getcwd() if it's not clear
    script_dir = os.getcwd()

data_dir = os.path.join(script_dir, "..", "tests","test_data")
file_path = os.path.join(data_dir, f"expected_{args.file}_metrics.json")

with open(file_path, "w", encoding="utf-8") as f:
    json.dump(metrics, f, indent=4, ensure_ascii=False)

# %%
metrics
# Out:
# {'migration_tag': '2025-04-11_16h35_InfoClimat',
#  'mongodb_address': 'mongodb://localhost:27017/',
#  'row_count': 1143,
#  'median_temperature_°C': 13.1,
#  'min_temperature_°C': 2.7,
#  'max_temperature_°C': 18.6,
#  'median_humidity_%': 87.0,
#  'min_humidity_%': 56.0,
#  'max_humidity_%': 100.0,
#  'median_pressure_hPa': 1005.5,
#  'min_pressure_hPa': 997.2,
#  'max_pressure_hPa': 1020.7}

# %%
# Insert documents
try:
    # Insert documents, set 'ordered=False' to continue on duplicate key error
    result = collection.insert_many(processed_data, ordered=False)

    # Log the number of inserted documents
    inserted_count = len(result.inserted_ids)
    logger.info(f"Successfully inserted {inserted_count} documents into MongoDB at {mongodb_address}!")

except errors.BulkWriteError as e:
    # Extract useful summary info without dumping full error
    inserted_count = e.details.get('nInserted', 0)
    write_errors = e.details.get('writeErrors', [])
    duplicate_count = 0
    validation_count = 0
    other_count = 0

    # Separate errors into categories
    for error in write_errors:
        if error.get('code') == 11000:  # Duplicate key error
            duplicate_count += 1
        elif error.get('code') == 121:  # Validation error
            validation_count += 1
        else:  # Other errors
            other_count += 1

    # Log the counts of different error types
    logger.warning(f"Duplicate key error: {duplicate_count} documents were skipped.")
    logger.warning(f"Validation error: {validation_count} documents failed validation.")
    logger.warning(f"Other errors: {other_count} documents encountered other errors.")

    # Successfully inserted documents
    logger.info(f"{inserted_count} documents were successfully inserted despite this error.")

    # Log the first 3 duplicate _id values
    duplicate_key_errors_handled = 0
    for error in write_errors:
        if error.get('code') == 11000 and duplicate_key_errors_handled < 3:  # Duplicate key error
            errmsg = error.get('errmsg', 'No detailed message available')
            logger.info(f"Duplicate key error: {errmsg}")

            # Extract the duplicate key information from the error details
            dup_id = error.get('keyValue', {}).get('_id', 'unknown')
            logger.debug(f"Duplicate _id: {dup_id}")

            # Log the failed document data for duplicate key errors
            logger.info(f"Failed document data for duplicate key: {error.get('op', {})}")
            duplicate_key_errors_handled += 1

    if duplicate_count > 3:
        logger.info(f"...and {duplicate_count - 3} more duplicates were skipped.")

    # Log the first 3 validation errors
    validation_errors_handled = 0
    for error in write_errors:
        if error.get('code') == 121 and validation_errors_handled < 3:  # Validation error
            errmsg = error.get('errmsg', 'No detailed message available')
            logger.info(f"Validation failed for document: {errmsg}")
            logger.info(f"Failed document data for validation error: {error.get('op', {})}")
            validation_errors_handled += 1

    if validation_count > 3:
        logger.debug(f"...and {validation_count - 3} more validation errors occurred.")

    # If there are any other errors (non-validation, non-duplicate), log them
    if other_count > 0:
        logger.debug(f"...and {other_count} other errors occurred.")
# Out:
# WARNING:__main__:Duplicate key error: 1143 documents were skipped.
# WARNING:__main__:Validation error: 0 documents failed validation.
# WARNING:__main__:Other errors: 0 documents encountered other errors.
# INFO:__main__:0 documents were successfully inserted despite this error.
# INFO:__main__:Duplicate key error: E11000 duplicate key error collection: weather_data.weather_station index: _id_ dup key: { _id: ObjectId('6844ef7d013a32b44e5c1b85') }
# INFO:__main__:Failed document data for duplicate key: {'id_station': '07015', 'station': 'Lille-Lesquin', 'datetime': datetime.datetime(2024, 10, 5, 0, 0), 'temperature_°C': 7.6, 'pressure_hPa': 1020.7, 'humidity_%': 89, 'dew_point_°C': 5.9, 'visibility_m': 6000, 'wind_speed_kph': 3.6, 'wind_gust_kph': 7.2, 'wind_dir': 90, 'precip_rate_mm/hr (3hrs)': 0.0, 'precip_rate_mm/hr': 0.0, 'snow_depth_mm': None, 'cloud_coverage': '', 'solar_w/m²': None, '_id': ObjectId('6844ef7d013a32b44e5c1b85'), 'migrated': '2025-04-11_16h35_InfoClimat'}
# INFO:__main__:Duplicate key error: E11000 duplicate key error collection: weather_data.weather_station index: _id_ dup key: { _id: ObjectId('3df7545ee2ade0bcbb51b66d') }
# INFO:__main__:Failed document data for duplicate key: {'id_station': '07015', 'station': 'Lille-Lesquin', 'datetime': datetime.datetime(2024, 10, 5, 1, 0), 'temperature_°C': 7.5, 'pressure_hPa': 1020.6, 'humidity_%': 92, 'dew_point_°C': 6.3, 'visibility_m': 7000, 'wind_speed_kph': 3.6, 'wind_gust_kph': 7.2, 'wind_dir': 30, 'precip_rate_mm/hr (3hrs)': None, 'precip_rate_mm/hr': 0.0, 'snow_depth_mm': None, 'cloud_coverage': '', 'solar_w/m²': None, '_id': ObjectId('3df7545ee2ade0bcbb51b66d'), 'migrated': '2025-04-11_16h35_InfoClimat'}
# INFO:__main__:Duplicate key error: E11000 duplicate key error collection: weather_data.weather_station index: _id_ dup key: { _id: ObjectId('e183902f3204cf2d03876c4c') }
# INFO:__main__:Failed document data for duplicate key: {'id_station': '07015', 'station': 'Lille-Lesquin', 'datetime': datetime.datetime(2024, 10, 5, 2, 0), 'temperature_°C': 7.4, 'pressure_hPa': 1020.3, 'humidity_%': 93, 'dew_point_°C': 6.3, 'visibility_m': 4400, 'wind_speed_kph': 7.2, 'wind_gust_kph': 7.2, 'wind_dir': 40, 'precip_rate_mm/hr (3hrs)': None, 'precip_rate_mm/hr': 0.0, 'snow_depth_mm': None, 'cloud_coverage': '', 'solar_w/m²': 10.0, '_id': ObjectId('e183902f3204cf2d03876c4c'), 'migrated': '2025-04-11_16h35_InfoClimat'}
# INFO:__main__:...and 1140 more duplicates were skipped.

# %%
# ✅ 6. Verify Data
print("Sample Data from MongoDB:")
pipeline = [
    {
        "$group": {
            "_id": "$station",  # Group by id_station
            "first_document": {"$first": "$$ROOT"}  # Take the first document for each id_station
        }
    },
    {
        "$replaceRoot": {"newRoot": "$first_document"}  # Replace the root document with the first document
    }
]
# Execute the aggregation
result = collection.aggregate(pipeline)

# Fetch the results
distinct_documents = list(result)

# Print the result
for doc in distinct_documents:
    print(doc)
# Out:
# Sample Data from MongoDB:
# {'_id': ObjectId('bf86dddda3e00d73c6ffae57'), 'id_station': 'STATIC0010', 'station': 'Hazebrouck', 'datetime': datetime.datetime(2024, 10, 5, 0, 0), 'temperature_°C': 4.7, 'pressure_hPa': 1020.6, 'humidity_%': 97, 'dew_point_°C': 4.2, 'visibility_m': None, 'wind_speed_kph': 0.0, 'wind_gust_kph': None, 'wind_dir': 0, 'precip_rate_mm/hr (3hrs)': None, 'precip_rate_mm/hr': 0.0, 'snow_depth_mm': None, 'cloud_coverage': '', 'solar_w/m²': None, 'migrated': '2025-04-11_15h46_InfoClimat'}
# {'_id': ObjectId('6e1a6c974f15e7f5c7150232'), 'id_station': '000R5', 'station': 'Bergues', 'datetime': datetime.datetime(2024, 10, 5, 0, 0), 'temperature_°C': 8.4, 'pressure_hPa': 1019.3, 'humidity_%': 86, 'dew_point_°C': 6.2, 'visibility_m': None, 'wind_speed_kph': 1.4, 'wind_gust_kph': None, 'wind_dir': 113, 'precip_rate_mm/hr (3hrs)': 0.0, 'precip_rate_mm/hr': 0.0, 'snow_depth_mm': None, 'cloud_coverage': '', 'solar_w/m²': None, 'migrated': '2025-04-11_15h46_InfoClimat'}
# {'_id': ObjectId('6844ef7d013a32b44e5c1b85'), 'id_station': '07015', 'station': 'Lille-Lesquin', 'datetime': datetime.datetime(2024, 10, 5, 0, 0), 'temperature_°C': 7.6, 'pressure_hPa': 1020.7, 'humidity_%': 89, 'dew_point_°C': 5.9, 'visibility_m': 6000, 'wind_speed_kph': 3.6, 'wind_gust_kph': 7.2, 'wind_dir': 90, 'precip_rate_mm/hr (3hrs)': 0.0, 'precip_rate_mm/hr': 0.0, 'snow_depth_mm': None, 'cloud_coverage': '', 'solar_w/m²': None, 'migrated': '2025-04-11_15h46_InfoClimat'}
# {'_id': ObjectId('05cfc351250674cec2eaef31'), 'station': 'Ichtegem', 'datetime': datetime.datetime(2024, 10, 1, 0, 4), 'temperature_°C': 13.8, 'dew_point_°C': 11.7, 'humidity_%': 87, 'wind_dir': 247.5, 'wind_speed_kph': 13.2, 'wind_gust_kph': 16.7, 'pressure_hPa': 998.3, 'precip_rate_mm/hr': 0.0, 'precip_accum_mm': 0.0, 'uv_index': 0.0, 'solar_w/m²': 0.0, 'migrated': '2025-04-11_15h46_Ichtegem'}
# {'_id': ObjectId('71c8e8f799078de58b277081'), 'id_station': '00052', 'station': 'Armentières', 'datetime': datetime.datetime(2024, 10, 5, 0, 0), 'temperature_°C': 6.4, 'pressure_hPa': 1019.1, 'humidity_%': 95, 'dew_point_°C': 5.6, 'visibility_m': None, 'wind_speed_kph': 0.0, 'wind_gust_kph': None, 'wind_dir': 134, 'precip_rate_mm/hr (3hrs)': None, 'precip_rate_mm/hr': 0.0, 'snow_depth_mm': None, 'cloud_coverage': '', 'solar_w/m²': None, 'migrated': '2025-04-11_15h46_InfoClimat'}
# {'_id': ObjectId('553a8a0d4255f9f2313e5707'), 'station': 'Madeleine', 'datetime': datetime.datetime(2024, 10, 1, 0, 4), 'temperature_°C': 13.4, 'dew_point_°C': 10.7, 'humidity_%': 84, 'wind_dir': nan, 'wind_speed_kph': 7.1, 'wind_gust_kph': 17.5, 'pressure_hPa': 1007.5, 'precip_rate_mm/hr': 0.0, 'precip_accum_mm': 4.8, 'uv_index': 0.0, 'solar_w/m²': 0.0, 'migrated': '2025-04-11_15h46_Madeleine'}
